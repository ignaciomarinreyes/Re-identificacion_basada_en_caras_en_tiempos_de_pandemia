# %%
# Ver características de la gráfica
# !nvidia-smi

# %%
# Montar Drive
from google.colab import drive
drive.mount('/content/gdrive')

# %%
cd "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort"

# %%
# Instalar dependencias yolov4
# !pip3 install -r requirements.txt
# !python save_model.py --model yolov4

# %%
# Ejecutar yolov4
#!python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail20_Prueba/"
#python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail20/"
#!python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail19/"
#!python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail21/"

# %%
# !python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail19/"
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/insightface.py" "/content/gdrive/My Drive/TFG/data/LPATrail20/"
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/insightface.py" "/content/gdrive/My Drive/TFG/data/LPATrail19/"

# %%
# Instalar dependencias insightface
# !pip uninstall -y mxnet && pip install mxnet-cu101
# !pip3 install insightface

# %%
cd "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython/"

# %%
# Compilar pyx de cython, para obtener los .c
# !python3 setup.py install

# %%
# Ejecutar InsightFace
#!python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/insightface.py" "/content/gdrive/My Drive/TFG/data/LPATrail19/"
#!python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/insightface.py" "/content/gdrive/My Drive/TFG/data/LPATrail20/"
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/insightface.py" "/content/gdrive/My Drive/TFG/data/LPATrail21/"

# %%
#GroupDetection
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/groupDetection.py" "/content/gdrive/My Drive/TFG/data/LPATrail19/"
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/groupDetection.py" "/content/gdrive/My Drive/TFG/data/LPATrail20/"
# !python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/groupDetection.py" "/content/gdrive/My Drive/TFG/data/LPATrail21/"

# %%
#Obtener bodies
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/getBodies.py" "/content/gdrive/My Drive/TFG/data/LPATrail19/" "/content/gdrive/My Drive/TFG/data/Bodies_LPATrail19/"
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/getBodies.py" "/content/gdrive/My Drive/TFG/data/LPATrail20/" "/content/gdrive/My Drive/TFG/data/Bodies_LPATrail20/"
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/getBodies.py" "/content/gdrive/My Drive/TFG/data/LPATrail21/" "/content/gdrive/My Drive/TFG/data/Bodies_LPATrail21/"

# %%
#MakeFolderById
# !python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/makeFolderById.py" "/content/gdrive/My Drive/TFG/data/Reidentification/"
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/makeFolderById.py" "/content/gdrive/My Drive/TFG/data/Reidentification_1/"

# %%
#RenameFramePlace
# !python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/renameFramePlace.py" "/content/gdrive/My Drive/TFG/data/Reidentification"

# %%
#GetOneBodyId
# !python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/getOneBodyId.py" "/content/gdrive/My Drive/TFG/data/Reidentification/Tafira_Universidad" "/content/gdrive/My Drive/TFG/data/Reidentification/Tafira_Universidad_OneID" 
# !python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/getOneBodyId.py" "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira" "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira_OneID"

# %%
#EqualIdDir
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/equalIdDir.py" "/content/gdrive/My Drive/TFG/data/Reidentification/Tafira_Universidad" "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira"

# %%
#Instalar dependencias deepFace
# !pip3 install deepFace
# !pip3 install --upgrade tensorflow
# !pip3 install --upgrade tensorflow-gpu

# %%
#Copiar modelo deepFace a donde lo carga, debido a que no lo puede descargar
# !mkdir -p "/root/.deepface/weights"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/retinaface.h5" "/root/.deepface/weights/retinaface.h5"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/facenet_weights.h5" "/root/.deepface/weights/facenet_weights.h5"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/deepid_keras_weights.h5" "/root/.deepface/weights/deepid_keras_weights.h5"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/arcface_weights.h5" "/root/.deepface/weights/arcface_weights.h5"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/vgg_face_weights.h5" "/root/.deepface/weights/vgg_face_weights.h5"

# %%
#DeepFace
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -v 
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -die 
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -r1
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -ap
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -ap -p "/content/gdrive/My Drive/TFG/data/Reidentification_Prueba"

# %%
#AlignedReID
#!python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -v
#!python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -d 
# !python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -r1 

#!python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -ap
#!python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -ap -p "/content/gdrive/My Drive/TFG/data/Reidentification_Prueba"

# %%
#!find "/content/gdrive/My Drive/TFG/data/LPATrail19/" -name '*.txt' -delete
#!find "/content/gdrive/My Drive/TFG/data/LPATrail20/" -name '*.txt' -delete

# %%
#!find "/content/gdrive/My Drive/TFG/data/LPATrail21/" -name '*.jpg' | wc -l
#!find "/content/gdrive/My Drive/TFG/data/Otros/TafiraUniversidadSinMascarilla" -name '*.jpg' | wc -l
#!find "/content/gdrive/My Drive/TFG/data/Reidentification/TafiraUniversidadConMascarilla" -name '*.jpg' | wc -l
#!find "/content/gdrive/My Drive/TFG/data/Otros/UniversidadTafiraSinMascarilla" -name '*.jpg' | wc -l
#!find "/content/gdrive/My Drive/TFG/data/Reidentification/UniversidadTafiraConMascarilla" -name '*.jpg' | wc -l
#!find "/content/gdrive/My Drive/TFG/data/Otros/TafiraUniversidadSinMascarilla" -name '*.jpg' | wc -l


# !ls "/content/gdrive/My Drive/TFG/data/Otros/UniversidadTafiraSinMascarilla" | wc -l
#!ls "/content/gdrive/My Drive/TFG/data/Otros/TafiraUniversidadSinMascarilla" | wc -l
#!find "/content/gdrive/My Drive/TFG/data/Otros/TafiraUniversidadSinMascarilla" -name '*.jpg'

# %%
#!find "/content/gdrive/My Drive/TFG/data/LPATrail20/" -name 'Salida_frame_frame*' 
#!find "/content/gdrive/My Drive/TFG/data/LPATrail19/" -name  'Salida_frame_frame_13_27_50_200.jpg'

# %%
#!find "/content/gdrive/My Drive/TFG/data/LPATrail21/" -name '*_bodies.txt'

# %%
#!cp -r "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira/" "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_/"

# %%
#!mv "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira/601/"* "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira/599" 
#!rm -f -d "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira/601/"

# %%
# !cp -r "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira_Sin_Mascarilla" "/content/gdrive/My Drive/TFG/data/Copias/Universidad_Tafira_Sin_Mascarilla"

# %%
#!rm -f -d -r "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira/4/"

# %%
#Copiar carpeta Con Mascarilla
referencia="217"
comparado="1605"

# !mkdir "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira_Con_Mascarilla/$referencia" 
# !cp "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira/$comparado/"* "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira_Con_Mascarilla/$referencia" 
# !mkdir "/content/gdrive/My Drive/TFG/data/Reidentification/Tafira_Universidad_Con_Mascarilla/$referencia" 
# !cp "/content/gdrive/My Drive/TFG/data/Reidentification/Tafira_Universidad/$referencia/"* "/content/gdrive/My Drive/TFG/data/Reidentification/Tafira_Universidad_Con_Mascarilla/$referencia"

# %%
#Copiar carpeta Sin Mascarilla
referencia="224"
comparado="605"

# !mkdir "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira_Sin_Mascarilla/$referencia" 
# !cp "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira/$comparado/"* "/content/gdrive/My Drive/TFG/data/Reidentification/Universidad_Tafira_Sin_Mascarilla/$referencia" 
# !mkdir "/content/gdrive/My Drive/TFG/data/Reidentification/Tafira_Universidad_Sin_Mascarilla/$referencia" 
# !cp "/content/gdrive/My Drive/TFG/data/Reidentification/Tafira_Universidad/$referencia/"* "/content/gdrive/My Drive/TFG/data/Reidentification/Tafira_Universidad_Sin_Mascarilla/$referencia"

# %%
# !find "/content/gdrive/My Drive/TFG/data/Reidentification/TafiraUniversidadConMascarilla" -name '*Market1501_Resnet50_AlignedReIdDistance.txt'

# %%
#DeepFace
from deepface import DeepFace
path = "/content/gdrive/My Drive/TFG/data/Reidentification/"
result  = DeepFace.verify(path + "TafiraUniversidadSinMascarilla/20/12_01_39_600_20_body.jpg", path + "UniversidadTafiraSinMascarilla/20/14_00_17_200_20_body.jpg")
print("Is verified: ", result["distance"])
# Is verified:  0.10833883195064697
#1_Tafira_Universidad_Sin_Mascarilla 12_01_39_600 20 2_Universidad_Tafira_Sin_Mascarilla 14_00_17_200 20 0.10833888398046487 0.14751565349008525 0.4654865926758039

# %%
#!find "/content/gdrive/My Drive/TFG/data/LPATrail21" -name '*.txt' 
# !find "/content/gdrive/My Drive/TFG/data/LPATrail21" -name '*.txt' | xargs -I '{}' cp {} -t "/content/gdrive/My Drive/TFG/data/Face"

# %%
# !unzip -j "/content/gdrive/My Drive/TFG/data/LPATrail21/tagged.zip"
