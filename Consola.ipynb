# %%
# Ver características de la gráfica
# !nvidia-smi

# %%
# Montar Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort"
# Out:
# /content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort

# %%
# Instalar dependencias yolov4
# !pip3 install -r requirements.txt
# !python save_model.py --model yolov4

# %%
# Ejecutar yolov4
# !python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/object_tracker.py" --video ./data/video/test.mp4 --output ./outputs/demo.avi --model yolov4

# %%
# Instalar dependencias insightface
# !pip uninstall -y mxnet && pip install mxnet-cu101
# !pip3 install insightface

# %%
cd "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython/"
# Out:
# /content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython

# %%
# Compilar pyx de cython, para obtener los .c
# !python3 setup.py install

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados sin crear imagenes recortadas, crea los txt de los box de las caras
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face_2.py"
# Out:
# [19:44:38] ../src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v1.5.0. Attempting to upgrade...
# [19:44:38] ../src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_42_600_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_42_800_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_000_bodies.txt
# ===========================================
# 1 1357 276 124 329
# [19:44:42] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 2 1120 269 41 109
# [19:44:43] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 4 1060 287 42 81
# [19:44:45] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 32) (1, 6, 20, 32)
# (1, 4, 40, 63) (1, 6, 40, 63)
# (1, 4, 80, 125) (1, 6, 80, 125)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_200_bodies.txt
# ===========================================
# 1 1351 273 127 336
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 2 1119 270 39 104
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 4 1058 299 39 75
# (1, 4, 20, 32) (1, 6, 20, 32)
# (1, 4, 40, 63) (1, 6, 40, 63)
# (1, 4, 80, 125) (1, 6, 80, 125)
# find 1 faces
# 0 [ 0 11 14 24] 0.9725989
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_200_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_400_bodies.txt
# ===========================================
# 1 1341 278 123 325
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 2 1119 273 39 101
# [19:44:48] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 4 1058 289 42 81
# (1, 4, 20, 32) (1, 6, 20, 32)
# (1, 4, 40, 63) (1, 6, 40, 63)
# (1, 4, 80, 125) (1, 6, 80, 125)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_600_bodies.txt
# ===========================================
# 1 1334 276 122 321
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 2 1117 273 40 102
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 4 1059 298 39 75
# (1, 4, 20, 32) (1, 6, 20, 32)
# (1, 4, 40, 63) (1, 6, 40, 63)
# (1, 4, 80, 125) (1, 6, 80, 125)
# find 0 faces
# ===========================================
# 7 873 289 46 113
# [19:44:49] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_800_bodies.txt
# ===========================================
# 1 1334 278 120 319
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 2 1116 274 38 98
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 4 1061 298 39 77
# (1, 4, 20, 32) (1, 6, 20, 32)
# (1, 4, 40, 63) (1, 6, 40, 63)
# (1, 4, 80, 125) (1, 6, 80, 125)
# find 1 faces
# 0 [24  0 32 10] 0.87577295
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_800_faces.txt
# ===========================================
# 7 867 288 48 118
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 1 faces
# 0 [17 15 44 38] 0.82344353
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_800_faces.txt
# ===========================================
# 8 997 295 39 80
# [19:44:52] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 30) (1, 6, 20, 30)
# (1, 4, 40, 60) (1, 6, 40, 60)
# (1, 4, 80, 120) (1, 6, 80, 120)
# find 2 faces
# 0 [ 0  0 17 17] 0.9784903
# 1 [23  0 38 17] 0.9322751
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_800_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_000_bodies.txt
# ===========================================
# 1 1335 276 116 312
# [19:44:53] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1113 274 37 96
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 4 1061 300 39 77
# (1, 4, 20, 32) (1, 6, 20, 32)
# (1, 4, 40, 63) (1, 6, 40, 63)
# (1, 4, 80, 125) (1, 6, 80, 125)
# find 0 faces
# ===========================================
# 7 860 284 47 116
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 2 faces
# 0 [13 11 23 24] 0.97207695
# 1 [35  0 46 11] 0.8738023
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_000_faces.txt
# ===========================================
# 8 994 284 57 117
# [19:44:55] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 30) (1, 6, 20, 30)
# (1, 4, 40, 59) (1, 6, 40, 59)
# (1, 4, 80, 117) (1, 6, 80, 117)
# find 1 faces
# 0 [18  1 33 18] 0.99307865
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_000_faces.txt
# ===========================================
# 9 1075 282 37 85
# [19:44:57] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 106) (1, 6, 80, 106)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_200_bodies.txt
# ===========================================
# 1 1333 271 116 312
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1112 272 40 101
# [19:44:59] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 1 faces
# 0 [14  3 25 18] 0.7111644
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_200_faces.txt
# ===========================================
# 7 856 298 45 112
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 1 faces
# 0 [12  0 23 13] 0.9898526
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_200_faces.txt
# ===========================================
# 8 996 284 58 119
# (1, 4, 20, 30) (1, 6, 20, 30)
# (1, 4, 40, 60) (1, 6, 40, 60)
# (1, 4, 80, 119) (1, 6, 80, 119)
# find 1 faces
# 0 [15  4 31 23] 0.9947661
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_200_faces.txt
# ===========================================
# 9 1070 286 34 79
# [19:45:01] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 105) (1, 6, 80, 105)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_400_bodies.txt
# ===========================================
# 1 1330 274 114 305
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 2 1109 275 45 116
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 4 1045 296 45 88
# (1, 4, 20, 32) (1, 6, 20, 32)
# (1, 4, 40, 63) (1, 6, 40, 63)
# (1, 4, 80, 125) (1, 6, 80, 125)
# find 1 faces
# 0 [17 14 26 26] 0.92259437
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_400_faces.txt
# ===========================================
# 7 848 290 47 119
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 1 faces
# 0 [ 8  3 19 17] 0.8613678
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_400_faces.txt
# ===========================================
# 8 997 282 64 130
# (1, 4, 20, 30) (1, 6, 20, 30)
# (1, 4, 40, 60) (1, 6, 40, 60)
# (1, 4, 80, 120) (1, 6, 80, 120)
# find 1 faces
# 0 [18  7 32 24] 0.98850703
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_400_faces.txt
# ===========================================
# 9 1067 286 34 78
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 105) (1, 6, 80, 105)
# find 1 faces
# 0 [11  0 29 17] 0.72179514
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_400_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_600_bodies.txt
# ===========================================
# 1 1323 276 112 299
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 2 1111 285 41 105
# [19:45:05] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 4 1043 296 43 86
# [19:45:06] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 31) (1, 6, 20, 31)
# (1, 4, 40, 62) (1, 6, 40, 62)
# (1, 4, 80, 123) (1, 6, 80, 123)
# find 0 faces
# ===========================================
# 7 838 290 51 128
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 1 faces
# 0 [12  6 24 21] 0.9739672
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_600_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_800_bodies.txt
# ===========================================
# 1 1324 277 110 296
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1111 283 36 88
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 1 faces
# 0 [ 1  0 20 15] 0.96595544
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_800_faces.txt
# ===========================================
# 4 1042 296 43 86
# (1, 4, 20, 31) (1, 6, 20, 31)
# (1, 4, 40, 62) (1, 6, 40, 62)
# (1, 4, 80, 123) (1, 6, 80, 123)
# find 0 faces
# ===========================================
# 7 830 289 53 134
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 1 faces
# 0 [15  2 27 18] 0.91720736
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_800_faces.txt
# ===========================================
# 8 979 275 77 160
# (1, 4, 20, 30) (1, 6, 20, 30)
# (1, 4, 40, 59) (1, 6, 40, 59)
# (1, 4, 80, 117) (1, 6, 80, 117)
# find 1 faces
# 0 [26 19 37 34] 0.75575536
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_800_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_000_bodies.txt
# ===========================================
# 1 1326 283 106 286
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1110 281 36 87
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ===========================================
# 4 1041 294 43 89
# (1, 4, 20, 30) (1, 6, 20, 30)
# (1, 4, 40, 60) (1, 6, 40, 60)
# (1, 4, 80, 119) (1, 6, 80, 119)
# find 0 faces
# ===========================================
# 7 825 292 51 131
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 2 faces
# 0 [10  2 23 18] 0.9610023
# 1 [12 30 27 42] 0.025046363
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_000_faces.txt
# ===========================================
# 8 979 273 82 172
# [19:45:09] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 58) (1, 6, 40, 58)
# (1, 4, 80, 116) (1, 6, 80, 116)
# find 1 faces
# 0 [30 16 43 30] 0.9461267
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_000_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_200_bodies.txt
# ===========================================
# 1 1321 279 106 287
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1106 281 36 85
# [19:45:11] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 52) (1, 6, 40, 52)
# (1, 4, 80, 103) (1, 6, 80, 103)
# find 0 faces
# ===========================================
# 4 1041 294 42 91
# [19:45:12] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 56) (1, 6, 40, 56)
# (1, 4, 80, 112) (1, 6, 80, 112)
# find 0 faces
# ===========================================
# 7 814 292 52 136
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# 0 [12  5 24 21] 0.94634986
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_200_faces.txt
# ===========================================
# 8 978 274 79 168
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 57) (1, 6, 40, 57)
# (1, 4, 80, 113) (1, 6, 80, 113)
# find 1 faces
# 0 [30 17 46 37] 0.8701431
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_200_faces.txt
# ===========================================
# 1009 1077 292 30 70
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 105) (1, 6, 80, 105)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_400_bodies.txt
# ===========================================
# 1 1318 281 104 281
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1104 278 38 91
# [19:45:15] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 0 faces
# ===========================================
# 4 1040 295 41 88
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 57) (1, 6, 40, 57)
# (1, 4, 80, 114) (1, 6, 80, 114)
# find 1 faces
# 0 [0 0 9 9] 0.968159
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_400_faces.txt
# ===========================================
# 7 805 289 54 144
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 1 faces
# 0 [16  3 30 21] 0.9699386
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_400_faces.txt
# ===========================================
# 8 976 274 79 169
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 57) (1, 6, 40, 57)
# (1, 4, 80, 113) (1, 6, 80, 113)
# find 1 faces
# 0 [25 14 40 33] 0.7426915
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_400_faces.txt
# ===========================================
# 1009 1077 293 30 69
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 105) (1, 6, 80, 105)
# find 0 faces
# ===========================================
# 13 962 298 34 81
# [19:45:17] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 101) (1, 6, 80, 101)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_600_bodies.txt
# ===========================================
# 1 1312 280 104 279
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1098 274 48 120
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ===========================================
# 4 1035 295 43 92
# [19:45:19] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 58) (1, 6, 40, 58)
# (1, 4, 80, 115) (1, 6, 80, 115)
# find 0 faces
# ===========================================
# 7 796 289 55 147
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 2 faces
# 0 [17 10 30 28] 0.9317848
# 1 [ 0  6 11 20] 0.6853008
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_600_faces.txt
# ===========================================
# 8 975 273 79 172
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 56) (1, 6, 40, 56)
# (1, 4, 80, 111) (1, 6, 80, 111)
# find 0 faces
# ===========================================
# 1009 1071 285 36 82
# [19:45:21] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 54) (1, 6, 40, 54)
# (1, 4, 80, 107) (1, 6, 80, 107)
# find 0 faces
# ===========================================
# 13 960 294 35 85
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_800_bodies.txt
# ===========================================
# 1 1308 279 103 277
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1094 272 53 131
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 1 faces
# 0 [18  2 30 18] 0.95917
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_800_faces.txt
# ===========================================
# 4 1033 293 44 94
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 57) (1, 6, 40, 57)
# (1, 4, 80, 114) (1, 6, 80, 114)
# find 0 faces
# ===========================================
# 7 789 291 55 146
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 1 faces
# 0 [11  7 25 25] 0.94816786
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_800_faces.txt
# ===========================================
# 8 973 274 79 175
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 55) (1, 6, 40, 55)
# (1, 4, 80, 109) (1, 6, 80, 109)
# find 1 faces
# 0 [32 19 44 35] 0.9780824
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_800_faces.txt
# ===========================================
# 1009 1071 285 35 83
# [19:45:24] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# [19:45:24] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:104: If you see this message in the middle of training, you are probably using bucketing. Consider setting env variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable cudnn tuning.
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 52) (1, 6, 40, 52)
# (1, 4, 80, 104) (1, 6, 80, 104)
# find 1 faces
# 0 [ 0  0 18 15] 0.8418286
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_800_faces.txt
# ===========================================
# 13 957 297 35 87
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_000_bodies.txt
# ===========================================
# 1 1306 282 100 273
# [19:45:26] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 0 faces
# ===========================================
# 2 1090 269 56 141
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 1 faces
# 0 [20  3 33 20] 0.9754166
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_000_faces.txt
# ===========================================
# 4 1028 287 48 106
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 55) (1, 6, 40, 55)
# (1, 4, 80, 110) (1, 6, 80, 110)
# find 0 faces
# ===========================================
# 7 779 288 58 154
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 1 faces
# 0 [17  9 32 27] 0.95903325
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_000_faces.txt
# ===========================================
# 8 969 274 78 176
# [19:45:28] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 54) (1, 6, 40, 54)
# (1, 4, 80, 108) (1, 6, 80, 108)
# find 1 faces
# 0 [28 14 40 30] 0.93948406
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_000_faces.txt
# ===========================================
# 13 954 295 37 90
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_200_bodies.txt
# ===========================================
# 1 1305 281 96 261
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 2 1087 268 56 146
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 4 1026 291 46 104
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 55) (1, 6, 40, 55)
# (1, 4, 80, 109) (1, 6, 80, 109)
# find 0 faces
# ===========================================
# 7 773 289 56 152
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 1 faces
# 0 [18 14 33 33] 0.9629689
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_200_faces.txt
# ===========================================
# 8 970 284 74 166
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 54) (1, 6, 40, 54)
# (1, 4, 80, 108) (1, 6, 80, 108)
# find 1 faces
# 0 [22  9 37 27] 0.8806108
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_200_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_400_bodies.txt
# ===========================================
# 1 1303 283 94 254
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1082 266 58 154
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 1 faces
# 0 [21  6 32 20] 0.8123535
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_400_faces.txt
# ===========================================
# 4 1019 286 50 117
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 52) (1, 6, 40, 52)
# (1, 4, 80, 103) (1, 6, 80, 103)
# find 0 faces
# ===========================================
# 7 766 285 59 161
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [13 16 25 30] 0.8820967
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_400_faces.txt
# ===========================================
# 8 969 283 77 174
# [19:45:32] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 54) (1, 6, 40, 54)
# (1, 4, 80, 107) (1, 6, 80, 107)
# find 1 faces
# 0 [25  3 41 23] 0.90690213
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_400_faces.txt
# ===========================================
# 15 1138 287 27 81
# (1, 4, 20, 20) (1, 6, 20, 20)
# (1, 4, 40, 40) (1, 6, 40, 40)
# (1, 4, 80, 80) (1, 6, 80, 80)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_600_bodies.txt
# ===========================================
# 1 1297 283 93 252
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 2 1079 265 60 158
# [19:45:33] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 4 1016 297 47 111
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 0 faces
# ===========================================
# 7 760 289 56 154
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 2 faces
# 0 [13 10 28 29] 0.9451219
# 1 [ 0  0 10 16] 0.21750443
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_600_faces.txt
# ===========================================
# 1013 950 298 34 86
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# ===========================================
# 15 1137 286 27 80
# [19:45:35] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_800_bodies.txt
# ===========================================
# 1 1294 282 93 248
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 2 1075 269 56 146
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 2 faces
# 0 [ 0 35 14 47] 0.13916142
# 1 [22  4 36 21] 0.97701615
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_800_faces.txt
# ===========================================
# 4 1006 300 50 118
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 52) (1, 6, 40, 52)
# (1, 4, 80, 103) (1, 6, 80, 103)
# find 0 faces
# ===========================================
# 7 750 289 58 160
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 1 faces
# 0 [21  7 36 26] 0.9771573
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_800_faces.txt
# ===========================================
# 1013 947 297 36 88
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ===========================================
# 15 1140 282 30 88
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_000_bodies.txt
# ===========================================
# 1 1296 284 92 246
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1077 270 46 119
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 1 faces
# 0 [13  4 26 21] 0.6676406
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_000_faces.txt
# ===========================================
# 4 1004 305 46 113
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ===========================================
# 7 745 288 59 163
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 1 faces
# 0 [16  7 32 28] 0.9410066
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_000_faces.txt
# ===========================================
# 15 1138 300 25 71
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_200_bodies.txt
# ===========================================
# 1 1295 280 91 244
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 2 1073 272 44 109
# [19:45:38] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 1 faces
# 0 [10  2 24 19] 0.90489143
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_200_faces.txt
# ===========================================
# 4 1004 310 43 102
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 0 faces
# ===========================================
# 7 740 293 60 165
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 1 faces
# 0 [18  7 33 27] 0.9843912
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_200_faces.txt
# ===========================================
# 1008 948 300 75 169
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 54) (1, 6, 40, 54)
# (1, 4, 80, 108) (1, 6, 80, 108)
# find 1 faces
# 0 [34  0 51 13] 0.9680826
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_200_faces.txt
# ===========================================
# 15 1138 286 29 84
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_400_bodies.txt
# ===========================================
# 1 1295 281 91 241
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 2 1068 269 45 112
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 1 faces
# 0 [13  3 27 21] 0.85547394
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_400_faces.txt
# ===========================================
# 4 1001 312 43 102
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 0 faces
# ===========================================
# 7 735 282 64 177
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# 0 [27  8 44 30] 0.9775205
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_400_faces.txt
# ===========================================
# 1008 940 282 80 183
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 105) (1, 6, 80, 105)
# find 1 faces
# 0 [31  4 48 26] 0.9579115
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_400_faces.txt
# ===========================================
# 15 1137 296 28 78
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_600_bodies.txt
# ===========================================
# 1 1293 281 90 238
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 2 1055 266 62 155
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 1 faces
# 0 [23  8 39 29] 0.9469001
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_600_faces.txt
# ===========================================
# 7 737 286 63 178
# [19:45:42] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [22 10 38 32] 0.9763738
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_600_faces.txt
# ===========================================
# 1008 936 283 81 191
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 52) (1, 6, 40, 52)
# (1, 4, 80, 103) (1, 6, 80, 103)
# find 1 faces
# 0 [30 10 48 34] 0.90949214
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_600_faces.txt
# ===========================================
# 15 1135 295 29 83
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [11  4 28 26] 0.7235572
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_600_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_800_bodies.txt
# ===========================================
# 1 1288 279 91 238
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 2 1048 264 67 170
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 1 faces
# 0 [21  5 36 25] 0.960865
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_800_faces.txt
# ===========================================
# 7 737 287 65 183
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 2 faces
# 0 [15  7 32 29] 0.9874228
# 1 [ 0  0 35 45] 0.80299884
# Limit box: 737 287 35 45--->1 7
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_800_faces.txt
# ===========================================
# 1008 931 279 85 203
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 1 faces
# 0 [37  8 56 32] 0.89903647
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_800_faces.txt
# ===========================================
# 2013 925 291 40 99
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 0 faces
# ===========================================
# 15 1135 295 29 84
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [ 0  0 13 21] 0.77027917
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_800_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_000_bodies.txt
# ===========================================
# 1 1288 281 90 234
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 2 1041 266 67 173
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 1 faces
# 0 [22  9 38 28] 0.9625426
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_000_faces.txt
# ===========================================
# 7 732 279 69 198
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 1 faces
# 0 [25 18 39 35] 0.9291457
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_000_faces.txt
# ===========================================
# 1008 931 276 86 211
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 2 faces
# 0 [32 16 51 41] 0.943549
# 1 [67 13 79 28] 0.7778313
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_000_faces.txt
# ===========================================
# 2009 1108 298 33 77
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 106) (1, 6, 80, 106)
# find 0 faces
# ===========================================
# 2013 921 292 39 98
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# ===========================================
# 15 1138 299 28 78
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_200_bodies.txt
# ===========================================
# 1 1288 277 89 231
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 2 1033 264 69 176
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 1 faces
# 0 [27  7 44 28] 0.98797065
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_200_faces.txt
# ===========================================
# 7 730 284 70 199
# [19:45:45] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# 0 [23 21 42 45] 0.8793793
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_200_faces.txt
# ===========================================
# 1008 928 274 88 216
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 1 faces
# 0 [23 16 43 42] 0.9113148
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_200_faces.txt
# ===========================================
# 2009 1106 286 37 87
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 52) (1, 6, 40, 52)
# (1, 4, 80, 103) (1, 6, 80, 103)
# find 0 faces
# ===========================================
# 2013 918 291 39 100
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 15 1138 296 30 84
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_400_bodies.txt
# ===========================================
# 1 1288 277 88 230
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 2 1026 266 70 181
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 1 faces
# 0 [27  6 43 28] 0.982189
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_400_faces.txt
# ===========================================
# 7 731 287 69 199
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ===========================================
# 1008 923 271 90 221
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 2 faces
# 0 [ 6 21 14 30] 0.8810234
# 1 [30 20 45 40] 0.90967965
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_400_faces.txt
# ===========================================
# 2009 1108 296 33 79
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 0 faces
# ===========================================
# 15 1140 302 29 80
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 16 1076 285 41 114
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_600_bodies.txt
# ===========================================
# 1 1284 280 85 220
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 2 1019 268 71 184
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 1 faces
# 0 [25  4 41 26] 0.97107196
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_600_faces.txt
# ===========================================
# 1004 982 302 51 128
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# ===========================================
# 7 725 288 71 202
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# 0 [17 14 35 37] 0.9059709
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_600_faces.txt
# ===========================================
# 1008 919 275 91 224
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 2 faces
# 0 [36 22 52 42] 0.88923603
# 1 [67  4 82 22] 0.8685668
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_600_faces.txt
# ===========================================
# 2009 1108 290 33 78
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 0 faces
# ===========================================
# 15 1144 292 28 75
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 16 1074 290 39 108
# (1, 4, 20, 22) (1, 6, 20, 22)
# ...
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_000_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_bodies.txt
# ===========================================
# 1 1262 281 62 157
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ===========================================
# 2002 796 293 60 174
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [19  0 32 15] 0.9813912
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_faces.txt
# ===========================================
# 3004 994 288 54 147
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [14  0 28 16] 0.9089165
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_faces.txt
# ===========================================
# 7 800 273 175 506
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 2 faces
# 0 [15 18 29 36] 0.6557738
# 1 [ 95   0 126  24] 0.99082106
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_faces.txt
# ===========================================
# 1008 1158 250 189 514
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 3013 620 255 119 368
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 82, 80) (1, 6, 82, 80)
# find 0 faces
# ===========================================
# 15 1072 291 40 117
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 1 faces
# 0 [17  0 29  9] 0.1100694
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_faces.txt
# ===========================================
# 1016 915 298 69 191
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_bodies.txt
# ===========================================
# 1 1260 281 64 164
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 2002 787 290 62 181
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 2 faces
# 0 [23  5 37 21] 0.98811895
# 1 [ 9  4 20 19] 0.8650063
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_faces.txt
# ===========================================
# 3004 996 289 54 150
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# 0 [12  2 26 20] 0.98130417
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_faces.txt
# ===========================================
# 7 810 273 180 520
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 3 faces
# 0 [ 0 21 14 40] 0.053220343
# 1 [ 92 135 120 167] 0.014083369
# Limit box: 902 408 28 32--->0 7
# 2 [ 71 111 118 172] 0.08650106
# Limit box: 881 384 47 61--->0 7
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_faces.txt
# ===========================================
# 3013 626 262 122 384
# [19:46:07] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 42, 40) (1, 6, 42, 40)
# (1, 4, 84, 80) (1, 6, 84, 80)
# find 0 faces
# ===========================================
# 15 1067 290 40 118
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# ===========================================
# 19 836 234 152 394
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# 0 [ 67   7 102  50] 0.9885737
# Limit box: 903 241 35 43--->1 19
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_bodies.txt
# ===========================================
# 1 1260 282 65 166
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 2002 779 291 63 183
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [29  5 43 22] 0.9849866
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_faces.txt
# ===========================================
# 3004 990 282 56 160
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# 0 [11  5 24 19] 0.9836224
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_faces.txt
# ===========================================
# 1008 1084 238 224 605
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 3013 654 254 133 394
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# ===========================================
# 19 851 234 157 410
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 2 faces
# 0 [147  53 156  67] 0.060801983
# 1 [ 75  17 112  62] 0.9810884
# Limit box: 926 251 37 45--->1 19
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_bodies.txt
# ===========================================
# 1 1260 282 64 165
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 3004 990 282 58 163
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ===========================================
# 1008 1159 240 240 650
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 3013 668 257 144 421
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [132  34 143  52] 0.03360804
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_faces.txt
# ===========================================
# 15 1064 301 42 122
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ===========================================
# 19 864 233 165 429
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 2 faces
# 0 [102  10 141  58] 0.9365115
# Limit box: 966 243 39 48--->1 19
# 1 [38 53 52 72] 0.79131407
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_bodies.txt
# ===========================================
# 1 1257 286 63 161
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ===========================================
# 1008 1172 238 248 671
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 3013 700 237 158 461
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 0 faces
# ===========================================
# 15 1060 301 42 124
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# ===========================================
# 2016 873 283 81 230
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 2 faces
# 0 [29 18 46 39] 0.65477216
# 1 [48  0 60 13] 0.98409134
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_faces.txt
# ===========================================
# 19 896 222 174 458
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 1 faces
# 0 [25 61 36 74] 0.04989249
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_faces.txt
# ===========================================
# 26 1706 237 291 634
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_bodies.txt
# ===========================================
# 1 1258 284 62 159
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 3009 1150 291 23 60
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 3013 752 244 167 480
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 2 faces
# 0 [37 47 53 66] 0.2833303
# 1 [79 54 90 69] 0.39993525
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_faces.txt
# ===========================================
# 2016 864 282 83 236
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ===========================================
# 19 935 219 181 483
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 1 faces
# 0 [59 67 74 84] 0.10312002
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_faces.txt
# ===========================================
# 26 1645 235 320 702
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_bodies.txt
# ===========================================
# 1 1259 283 62 159
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 3002 760 290 68 203
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 1 faces
# 0 [23  9 39 28] 0.98518026
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_faces.txt
# ===========================================
# 3009 1153 291 22 57
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 3013 820 228 179 512
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# 0 [ 56  73  79 103] 0.68124014
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_faces.txt
# ===========================================
# 19 990 215 190 510
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 26 1658 236 336 737
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_bodies.txt
# ===========================================
# 1 1259 283 61 157
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 3002 754 286 72 211
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 2 faces
# 0 [44 11 56 24] 0.9911951
# 1 [18  9 34 28] 0.99265164
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_faces.txt
# ===========================================
# 1007 956 246 193 561
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [37 40 53 59] 0.061078608
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_faces.txt
# ===========================================
# 3013 826 225 185 528
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 5 faces
# 0 [168  61 184  81] 0.7830287
# 1 [77 57 90 74] 0.091663815
# 2 [ 82 102 100 127] 0.004609961
# 3 [49 69 69 95] 0.65845656
# 4 [144  83 160 103] 0.008187485
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_faces.txt
# ===========================================
# 2016 853 305 78 225
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 1 faces
# 0 [25 49 53 74] 0.14481723
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_faces.txt
# ===========================================
# 19 1059 221 195 525
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_bodies.txt
# ===========================================
# 3002 752 284 75 217
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 3 faces
# 0 [41 12 53 26] 0.98965466
# 1 [13 12 29 31] 0.9956351
# 2 [66 17 74 33] 0.25487244
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_faces.txt
# ===========================================
# 4004 973 282 67 195
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [18  7 32 25] 0.51228815
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_faces.txt
# ===========================================
# 1007 1026 219 220 616
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ===========================================
# 2008 1206 217 218 605
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ===========================================
# 1015 1065 328 41 113
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 2016 843 306 79 228
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 1 faces
# 0 [22  0 43 21] 0.8449508
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_faces.txt
# ===========================================
# 19 1074 219 202 544
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 3 faces
# 0 [144  16 201  92] 0.87629765
# Limit box: 1218 235 57 76--->1 19
# 1 [23 57 37 73] 0.027901484
# 2 [ 99  75 152 148] 0.3920755
# Limit box: 1173 294 53 73--->1 19
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_faces.txt

# %%
# Ejecutar modelo de identificación de mascarilla con test propio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_ignacio.py"

# %%
# Ejecutar modelo de identificación de mascarilla con cuerpos recortados
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_body.py"

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados creando imagenes recortadas
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face.py"

# %%
# Ver imagen
from IPython.display import Image
Image("/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/images/cov_Salida_frame_10_19_32_400_4.jpg", width=500)

# %%
# Ejecutar modelo de identificación de mascarilla con test del repositorio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test.py"

# %%
# Ejecutar modelos de reidentificación
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/gamodel-r50/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r34-amf/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r50-am-lfw/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r100-ii/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-y1-test2/model, 0'
