# %%
# Ver características de la gráfica
# !nvidia-smi

# %%
# Montar Drive
from google.colab import drive
drive.mount('/content/gdrive')

# %%
cd "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort"
# Out:
# /content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort

# %%
# Instalar dependencias yolov4
# !pip3 install -r requirements.txt
# !python save_model.py --model yolov4

# %%
# Ejecutar yolov4
#!python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/"
#!python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/"
# !python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail19Prueba/"

# %%
# Instalar dependencias insightface
# !pip uninstall -y mxnet && pip install mxnet-cu101
# !pip3 install insightface

# %%
cd "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython/"
# Out:
# /content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython

# %%
# Compilar pyx de cython, para obtener los .c
# !python3 setup.py install

# %%
# Ejecutar InsightFace
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/insightface.py"

# %%
# Ejecutar modelo de identificación de mascarilla con test del repositorio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test.py"

# %%
# Ejecutar modelos de reidentificación
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/gamodel-r50/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r34-amf/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r50-am-lfw/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r100-ii/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-y1-test2/model, 0'

# %%
#Instalar dependencias deepFace
# !pip3 install deepFace
# !pip3 install --upgrade tensorflow
# !pip3 install --upgrade tensorflow-gpu

# %%
#Copiar modelo deepFace a donde lo carga, debido a que no lo puede descargar
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/vgg_face_weights.h5" "/root/.deepface/weights/vgg_face_weights.h5"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/openface_weights.h5" "/root/.deepface/weights/openface_weights.h5"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/deepid_keras_weights.h5" "/root/.deepface/weights/deepid_keras_weights.h5"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/arcface_weights.h5" "/root/.deepface/weights/arcface_weights.h5"

# %%
#DeepFace
# !python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -v 
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -ie
# Out:
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_000_2002_body.png ===> VGG-Face
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_000_2002_body.png ===> Facenet
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_000_2002_body.png ===> OpenFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_000_2002_body.png ===> DeepFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_000_2002_body.png ===> DeepID
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_000_2002_body.png ===> Dlib
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_000_2002_body.png ===> ArcFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_200_2002_body.png ===> VGG-Face
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_200_2002_body.png ===> Facenet
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_200_2002_body.png ===> OpenFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_200_2002_body.png ===> DeepFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_200_2002_body.png ===> DeepID
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_200_2002_body.png ===> Dlib
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_200_2002_body.png ===> ArcFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_400_2002_body.png ===> VGG-Face
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_400_2002_body.png ===> Facenet
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_400_2002_body.png ===> OpenFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_400_2002_body.png ===> DeepFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_400_2002_body.png ===> DeepID
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_400_2002_body.png ===> Dlib
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_400_2002_body.png ===> ArcFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_800_2002_body.png ===> VGG-Face
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_800_2002_body.png ===> Facenet
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_800_2002_body.png ===> OpenFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_800_2002_body.png ===> DeepFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_800_2002_body.png ===> DeepID
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_800_2002_body.png ===> Dlib
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_19_800_2002_body.png ===> ArcFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_000_2002_body.png ===> VGG-Face
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_000_2002_body.png ===> Facenet
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_000_2002_body.png ===> OpenFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_000_2002_body.png ===> DeepFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_000_2002_body.png ===> DeepID
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_000_2002_body.png ===> Dlib
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_000_2002_body.png ===> ArcFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_200_2002_body.png ===> VGG-Face
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_200_2002_body.png ===> Facenet
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_200_2002_body.png ===> OpenFace
# /content/gdrive/My Drive/TFG/data/Reidentification/Tafira/2002/12_02_20_200_2002_body.png ===> DeepFace

# %%
#AlignedReID
# !python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -v
#!python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -d -e
#!python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -r1 -e

# %%
ls
