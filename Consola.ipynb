# %%
# Ver características de la gráfica
# !nvidia-smi

# %%
# Montar Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort"
# Out:
# /content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort

# %%
# Instalar dependencias yolov4
# !pip3 install -r requirements.txt
# !python save_model.py --model yolov4

# %%
# Ejecutar yolov4
# !python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/object_tracker.py" --video ./data/video/test.mp4 --output ./outputs/demo.avi --model yolov4
# Out:
# EMPIEZA
# Frame #:  1
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_42_600_bodies.txt
# FPS: 0.33
# Frame #:  2
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_42_800_bodies.txt
# FPS: 20.20
# Frame #:  3
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1357, 276, 1481, 605)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1120, 269, 1161, 378)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1060, 287, 1102, 368)
# FPS: 20.53
# Frame #:  4
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1351, 273, 1478, 609)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1119, 270, 1158, 374)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1058, 299, 1097, 374)
# FPS: 20.26
# Frame #:  5
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1341, 278, 1464, 603)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1119, 273, 1158, 374)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1058, 289, 1100, 370)
# FPS: 19.91
# Frame #:  6
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1334, 276, 1456, 597)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1117, 273, 1157, 375)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1059, 298, 1098, 373)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (873, 289, 919, 402)
# FPS: 18.87
# Frame #:  7
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_43_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1334, 278, 1454, 597)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1116, 274, 1154, 372)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1061, 298, 1100, 375)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (867, 288, 915, 406)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (997, 295, 1036, 375)
# FPS: 18.34
# Frame #:  8
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1335, 276, 1451, 588)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1113, 274, 1150, 370)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1061, 300, 1100, 377)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (860, 284, 907, 400)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (994, 284, 1051, 401)
# 2_newId 9
# Tracker ID: 9, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1075, 282, 1112, 367)
# FPS: 19.31
# Frame #:  9
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1333, 271, 1449, 583)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1112, 272, 1152, 373)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (856, 298, 901, 410)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (996, 284, 1054, 403)
# 2_newId 9
# Tracker ID: 9, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1070, 286, 1104, 365)
# FPS: 19.89
# 3_newID 4
# 4_repeticion 1
# Frame #:  10
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1330, 274, 1444, 579)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1109, 275, 1154, 391)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1045, 296, 1090, 384)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (848, 290, 895, 409)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (997, 282, 1061, 412)
# 2_newId 9
# Tracker ID: 9, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1067, 286, 1101, 364)
# FPS: 19.26
# Frame #:  11
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1323, 276, 1435, 575)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1111, 285, 1152, 390)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1043, 296, 1086, 382)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (838, 290, 889, 418)
# FPS: 19.30
# 3_newID 8
# 4_repeticion 1
# 3_newID 9
# 4_repeticion 1
# Frame #:  12
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_44_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1324, 277, 1434, 573)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1111, 283, 1147, 371)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1042, 296, 1085, 382)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (830, 289, 883, 423)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (979, 275, 1056, 435)
# FPS: 19.09
# 3_newID 9
# 4_repeticion 2
# 7_cabron9
# 5_oldId 9
# 6_dIncrement[oldId] 1000
# Frame #:  13
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1326, 283, 1432, 569)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1110, 281, 1146, 368)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1041, 294, 1084, 383)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (825, 292, 876, 423)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (979, 273, 1061, 445)
# FPS: 18.55
# 3_newID 9
# 4_repeticion 3
# Frame #:  14
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1321, 279, 1427, 566)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1106, 281, 1142, 366)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1041, 294, 1083, 385)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (814, 292, 866, 428)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (978, 274, 1057, 442)
# 1_1clave 9
# 1_2valor 1000
# 2_newId 1009
# Tracker ID: 1009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1077, 292, 1107, 362)
# FPS: 10.99
# 3_newID 9
# 4_repeticion 4
# Frame #:  15
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1318, 281, 1422, 562)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1104, 278, 1142, 369)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1040, 295, 1081, 383)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (805, 289, 859, 433)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (976, 274, 1055, 443)
# 1_1clave 9
# 1_2valor 1000
# 2_newId 1009
# Tracker ID: 1009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1077, 293, 1107, 362)
# 2_newId 13
# Tracker ID: 13, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (962, 298, 996, 379)
# FPS: 16.31
# 3_newID 9
# 4_repeticion 5
# Frame #:  16
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1312, 280, 1416, 559)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1098, 274, 1146, 394)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1035, 295, 1078, 387)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (796, 289, 851, 436)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (975, 273, 1054, 445)
# 1_1clave 9
# 1_2valor 1000
# 2_newId 1009
# Tracker ID: 1009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1071, 285, 1107, 367)
# 2_newId 13
# Tracker ID: 13, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (960, 294, 995, 379)
# FPS: 14.64
# 3_newID 9
# 4_repeticion 6
# Frame #:  17
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_45_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1308, 279, 1411, 556)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1094, 272, 1147, 403)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1033, 293, 1077, 387)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (789, 291, 844, 437)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (973, 274, 1052, 449)
# 1_1clave 9
# 1_2valor 1000
# 2_newId 1009
# Tracker ID: 1009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1071, 285, 1106, 368)
# 2_newId 13
# Tracker ID: 13, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (957, 297, 992, 384)
# FPS: 16.99
# 3_newID 9
# 4_repeticion 7
# Frame #:  18
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1306, 282, 1406, 555)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1090, 269, 1146, 410)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1028, 287, 1076, 393)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (779, 288, 837, 442)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (969, 274, 1047, 450)
# 2_newId 13
# Tracker ID: 13, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (954, 295, 991, 385)
# FPS: 16.27
# 3_newID 9
# 4_repeticion 8
# 3_newID 1009
# 4_repeticion 1
# Frame #:  19
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1305, 281, 1401, 542)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1087, 268, 1143, 414)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1026, 291, 1072, 395)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (773, 289, 829, 441)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (970, 284, 1044, 450)
# FPS: 16.20
# 3_newID 9
# 4_repeticion 9
# 3_newID 1009
# 4_repeticion 2
# 5_oldId 9
# 6_dIncrement[oldId] 2000
# 3_newID 13
# 4_repeticion 1
# Frame #:  20
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1303, 283, 1397, 537)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1082, 266, 1140, 420)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1019, 286, 1069, 403)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (766, 285, 825, 446)
# 2_newId 8
# Tracker ID: 8, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (969, 283, 1046, 457)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1138, 287, 1165, 368)
# FPS: 16.18
# 3_newID 9
# 4_repeticion 10
# 3_newID 1009
# 4_repeticion 3
# 3_newID 13
# 4_repeticion 2
# 7_cabron13
# 5_oldId 13
# 6_dIncrement[oldId] 1000
# Frame #:  21
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1297, 283, 1390, 535)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1079, 265, 1139, 423)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1016, 297, 1063, 408)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (760, 289, 816, 443)
# 1_1clave 13
# 1_2valor 1000
# 2_newId 1013
# Tracker ID: 1013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (950, 298, 984, 384)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1137, 286, 1164, 366)
# FPS: 16.24
# 3_newID 8
# 4_repeticion 1
# 3_newID 9
# 4_repeticion 11
# 3_newID 1009
# 4_repeticion 4
# 3_newID 13
# 4_repeticion 3
# Frame #:  22
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_46_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1294, 282, 1387, 530)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1075, 269, 1131, 415)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1006, 300, 1056, 418)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (750, 289, 808, 449)
# 1_1clave 13
# 1_2valor 1000
# 2_newId 1013
# Tracker ID: 1013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (947, 297, 983, 385)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1140, 282, 1170, 370)
# FPS: 17.18
# 3_newID 8
# 4_repeticion 2
# 7_cabron8
# 5_oldId 8
# 6_dIncrement[oldId] 1000
# 3_newID 9
# 4_repeticion 12
# 3_newID 1009
# 4_repeticion 5
# 3_newID 13
# 4_repeticion 4
# Frame #:  23
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1296, 284, 1388, 530)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1077, 270, 1123, 389)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1004, 305, 1050, 418)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (745, 288, 804, 451)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1138, 300, 1163, 371)
# FPS: 16.68
# 3_newID 8
# 4_repeticion 3
# 3_newID 9
# 4_repeticion 13
# 3_newID 1009
# 4_repeticion 6
# 3_newID 13
# 4_repeticion 5
# 3_newID 1013
# 4_repeticion 1
# Frame #:  24
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1295, 280, 1386, 524)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1073, 272, 1117, 381)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1004, 310, 1047, 412)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (740, 293, 800, 458)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (948, 300, 1023, 469)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1138, 286, 1167, 370)
# FPS: 16.35
# 3_newID 8
# 4_repeticion 4
# 3_newID 9
# 4_repeticion 14
# 3_newID 1009
# 4_repeticion 7
# 3_newID 13
# 4_repeticion 6
# 3_newID 1013
# 4_repeticion 2
# 5_oldId 13
# 6_dIncrement[oldId] 2000
# Frame #:  25
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1295, 281, 1386, 522)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1068, 269, 1113, 381)
# 2_newId 4
# Tracker ID: 4, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1001, 312, 1044, 414)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (735, 282, 799, 459)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (940, 282, 1020, 465)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1137, 296, 1165, 374)
# FPS: 16.03
# 3_newID 8
# 4_repeticion 5
# 3_newID 9
# 4_repeticion 15
# 3_newID 1009
# 4_repeticion 8
# 3_newID 13
# 4_repeticion 7
# 3_newID 1013
# 4_repeticion 3
# Frame #:  26
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1293, 281, 1383, 519)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1055, 266, 1117, 421)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (737, 286, 800, 464)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (936, 283, 1017, 474)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1135, 295, 1164, 378)
# FPS: 16.37
# 3_newID 4
# 4_repeticion 1
# 3_newID 8
# 4_repeticion 6
# 3_newID 9
# 4_repeticion 16
# 3_newID 1009
# 4_repeticion 9
# 3_newID 13
# 4_repeticion 8
# 3_newID 1013
# 4_repeticion 4
# Frame #:  27
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_47_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1288, 279, 1379, 517)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1048, 264, 1115, 434)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (737, 287, 802, 470)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (931, 279, 1016, 482)
# 1_1clave 13
# 1_2valor 2000
# 2_newId 2013
# Tracker ID: 2013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (925, 291, 965, 390)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1135, 295, 1164, 379)
# FPS: 16.20
# 3_newID 4
# 4_repeticion 2
# 7_cabron4
# 5_oldId 4
# 6_dIncrement[oldId] 1000
# 3_newID 8
# 4_repeticion 7
# 3_newID 9
# 4_repeticion 17
# 3_newID 1009
# 4_repeticion 10
# 3_newID 13
# 4_repeticion 9
# 3_newID 1013
# 4_repeticion 5
# Frame #:  28
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1288, 281, 1378, 515)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1041, 266, 1108, 439)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (732, 279, 801, 477)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (931, 276, 1017, 487)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1108, 298, 1141, 375)
# 1_1clave 13
# 1_2valor 2000
# 2_newId 2013
# Tracker ID: 2013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (921, 292, 960, 390)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1138, 299, 1166, 377)
# FPS: 14.30
# 3_newID 4
# 4_repeticion 3
# 3_newID 8
# 4_repeticion 8
# 3_newID 9
# 4_repeticion 18
# 3_newID 1009
# 4_repeticion 11
# 3_newID 13
# 4_repeticion 10
# 3_newID 1013
# 4_repeticion 6
# Frame #:  29
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1288, 277, 1377, 508)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1033, 264, 1102, 440)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (730, 284, 800, 483)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (928, 274, 1016, 490)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1106, 286, 1143, 373)
# 1_1clave 13
# 1_2valor 2000
# 2_newId 2013
# Tracker ID: 2013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (918, 291, 957, 391)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1138, 296, 1168, 380)
# FPS: 15.35
# 3_newID 4
# 4_repeticion 4
# 3_newID 8
# 4_repeticion 9
# 3_newID 9
# 4_repeticion 19
# 3_newID 1009
# 4_repeticion 12
# 3_newID 13
# 4_repeticion 11
# 3_newID 1013
# 4_repeticion 7
# Frame #:  30
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1288, 277, 1376, 507)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1026, 266, 1096, 447)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (731, 287, 800, 486)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (923, 271, 1013, 492)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1108, 296, 1141, 375)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1140, 302, 1169, 382)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1076, 285, 1117, 399)
# FPS: 5.87
# 3_newID 4
# 4_repeticion 5
# 3_newID 8
# 4_repeticion 10
# 3_newID 9
# 4_repeticion 20
# 3_newID 1009
# 4_repeticion 13
# 3_newID 13
# 4_repeticion 12
# 3_newID 1013
# 4_repeticion 8
# 3_newID 2013
# 4_repeticion 1
# Frame #:  31
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1284, 280, 1369, 500)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1019, 268, 1090, 452)
# 1_1clave 4
# 1_2valor 1000
# 2_newId 1004
# Tracker ID: 1004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (982, 302, 1033, 430)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (725, 288, 796, 490)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (919, 275, 1010, 499)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1108, 290, 1141, 368)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1144, 292, 1172, 367)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1074, 290, 1113, 398)
# FPS: 14.62
# 3_newID 4
# 4_repeticion 6
# 3_newID 8
# 4_repeticion 11
# 3_newID 9
# 4_repeticion 21
# 3_newID 1009
# 4_repeticion 14
# 3_newID 13
# 4_repeticion 13
# 3_newID 1013
# 4_repeticion 9
# 3_newID 2013
# 4_repeticion 2
# 5_oldId 13
# 6_dIncrement[oldId] 3000
# Frame #:  32
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_48_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1279, 275, 1366, 501)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1011, 267, 1081, 455)
# 1_1clave 4
# 1_2valor 1000
# 2_newId 1004
# Tracker ID: 1004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (978, 301, 1031, 433)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (721, 300, 791, 499)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (917, 274, 1010, 502)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1108, 285, 1142, 367)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1146, 293, 1177, 379)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1075, 296, 1110, 392)
# FPS: 15.10
# 3_newID 4
# 4_repeticion 7
# 3_newID 8
# 4_repeticion 12
# 3_newID 9
# 4_repeticion 22
# 3_newID 1009
# 4_repeticion 15
# 3_newID 13
# 4_repeticion 14
# 3_newID 1013
# 4_repeticion 10
# 3_newID 2013
# 4_repeticion 3
# Frame #:  33
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_49_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1275, 276, 1362, 502)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1005, 268, 1076, 459)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (714, 290, 788, 500)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (909, 276, 1004, 508)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1107, 300, 1138, 373)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1145, 293, 1179, 387)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1073, 290, 1111, 396)
# FPS: 14.19
# 3_newID 4
# 4_repeticion 8
# 3_newID 8
# 4_repeticion 13
# 3_newID 9
# 4_repeticion 23
# 3_newID 1009
# 4_repeticion 16
# 3_newID 13
# 4_repeticion 15
# 3_newID 1013
# 4_repeticion 11
# 3_newID 2013
# 4_repeticion 4
# 3_newID 1004
# 4_repeticion 1
# Frame #:  34
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_49_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1273, 271, 1359, 497)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (995, 268, 1067, 460)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (698, 287, 777, 506)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (904, 275, 1001, 518)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1110, 303, 1140, 375)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1147, 293, 1181, 388)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1069, 289, 1110, 400)
# FPS: 14.33
# 3_newID 4
# 4_repeticion 9
# 3_newID 8
# 4_repeticion 14
# 3_newID 9
# 4_repeticion 24
# 3_newID 1009
# 4_repeticion 17
# 3_newID 13
# 4_repeticion 16
# 3_newID 1013
# 4_repeticion 12
# 3_newID 2013
# 4_repeticion 5
# 3_newID 1004
# 4_repeticion 2
# 5_oldId 4
# 6_dIncrement[oldId] 2000
# Frame #:  35
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_49_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1270, 271, 1356, 497)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (987, 274, 1060, 475)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (684, 278, 770, 512)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (904, 277, 1002, 522)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1110, 302, 1142, 377)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1148, 298, 1181, 390)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1066, 292, 1106, 401)
# FPS: 13.96
# 3_newID 4
# 4_repeticion 10
# 3_newID 8
# 4_repeticion 15
# 3_newID 9
# 4_repeticion 25
# 3_newID 1009
# 4_repeticion 18
# 3_newID 13
# 4_repeticion 17
# 3_newID 1013
# 4_repeticion 13
# 3_newID 2013
# 4_repeticion 6
# 3_newID 1004
# 4_repeticion 3
# Frame #:  36
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_49_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1269, 275, 1352, 495)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (975, 265, 1051, 476)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (682, 287, 766, 519)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (897, 275, 998, 531)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1108, 299, 1142, 379)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1147, 293, 1184, 394)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1061, 289, 1104, 404)
# FPS: 15.29
# 3_newID 4
# 4_repeticion 11
# 3_newID 8
# 4_repeticion 16
# 3_newID 9
# 4_repeticion 26
# 3_newID 1009
# 4_repeticion 19
# 3_newID 13
# 4_repeticion 18
# 3_newID 1013
# 4_repeticion 14
# 3_newID 2013
# 4_repeticion 7
# 3_newID 1004
# 4_repeticion 4
# Frame #:  37
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_49_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1266, 277, 1348, 495)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (969, 265, 1044, 475)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (674, 290, 761, 525)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (890, 274, 993, 538)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1106, 299, 1140, 381)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1150, 306, 1183, 398)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1053, 296, 1096, 413)
# FPS: 14.64
# 3_newID 4
# 4_repeticion 12
# 3_newID 8
# 4_repeticion 17
# 3_newID 9
# 4_repeticion 27
# 3_newID 1009
# 4_repeticion 20
# 3_newID 13
# 4_repeticion 19
# 3_newID 1013
# 4_repeticion 15
# 3_newID 2013
# 4_repeticion 8
# 3_newID 1004
# 4_repeticion 5
# Frame #:  38
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_50_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1264, 281, 1345, 496)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (960, 266, 1033, 474)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (661, 283, 751, 532)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (888, 280, 986, 537)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1106, 300, 1142, 384)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1149, 302, 1182, 395)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1048, 301, 1090, 416)
# FPS: 15.34
# 3_newID 4
# 4_repeticion 13
# 3_newID 8
# 4_repeticion 18
# 3_newID 9
# 4_repeticion 28
# 3_newID 1009
# 4_repeticion 21
# 3_newID 13
# 4_repeticion 20
# 3_newID 1013
# 4_repeticion 16
# 3_newID 2013
# 4_repeticion 9
# 3_newID 1004
# 4_repeticion 6
# Frame #:  39
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_50_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1265, 276, 1345, 492)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (951, 268, 1026, 491)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (656, 293, 744, 540)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (886, 274, 989, 545)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1103, 305, 1136, 384)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1149, 297, 1183, 395)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1043, 301, 1087, 421)
# FPS: 14.82
# 3_newID 4
# 4_repeticion 14
# 3_newID 8
# 4_repeticion 19
# 3_newID 9
# 4_repeticion 29
# 3_newID 1009
# 4_repeticion 22
# 3_newID 13
# 4_repeticion 21
# 3_newID 1013
# 4_repeticion 17
# 3_newID 2013
# 4_repeticion 10
# 3_newID 1004
# 4_repeticion 7
# Frame #:  40
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_50_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1265, 277, 1344, 488)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (952, 265, 1007, 422)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (645, 286, 740, 552)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (884, 279, 988, 555)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1099, 301, 1134, 384)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1148, 295, 1184, 396)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1038, 300, 1083, 422)
# FPS: 15.27
# 3_newID 4
# 4_repeticion 15
# 3_newID 8
# 4_repeticion 20
# 3_newID 9
# 4_repeticion 30
# 3_newID 1009
# 4_repeticion 23
# 3_newID 13
# 4_repeticion 22
# 3_newID 1013
# 4_repeticion 18
# 3_newID 2013
# 4_repeticion 11
# 3_newID 1004
# 4_repeticion 8
# Frame #:  41
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_50_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1260, 282, 1336, 484)
# 2_newId 2
# Tracker ID: 2, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (945, 265, 1001, 421)
# 1_1clave 4
# 1_2valor 2000
# 2_newId 2004
# Tracker ID: 2004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (957, 272, 999, 375)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (635, 283, 732, 560)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (881, 276, 990, 568)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1099, 301, 1134, 387)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1147, 305, 1182, 401)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1034, 301, 1079, 423)
# FPS: 14.30
# 3_newID 4
# 4_repeticion 16
# 3_newID 8
# 4_repeticion 21
# 3_newID 9
# 4_repeticion 31
# 3_newID 1009
# 4_repeticion 24
# 3_newID 13
# 4_repeticion 23
# 3_newID 1013
# 4_repeticion 19
# 3_newID 2013
# 4_repeticion 12
# 3_newID 1004
# 4_repeticion 9
# Frame #:  42
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_50_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1256, 281, 1333, 484)
# 1_1clave 4
# 1_2valor 2000
# 2_newId 2004
# Tracker ID: 2004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (955, 270, 996, 372)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (623, 284, 724, 573)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (882, 269, 996, 576)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1099, 301, 1135, 388)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (807, 278, 891, 492)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1148, 310, 1181, 403)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1031, 301, 1076, 426)
# FPS: 14.89
# 3_newID 2
# 4_repeticion 1
# 3_newID 4
# 4_repeticion 17
# 3_newID 8
# 4_repeticion 22
# 3_newID 9
# 4_repeticion 32
# 3_newID 1009
# 4_repeticion 25
# 3_newID 13
# 4_repeticion 24
# 3_newID 1013
# 4_repeticion 20
# 3_newID 2013
# 4_repeticion 13
# 3_newID 1004
# 4_repeticion 10
# Frame #:  43
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_51_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1255, 284, 1332, 484)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (618, 279, 723, 578)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (877, 273, 995, 588)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1097, 297, 1134, 389)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (794, 279, 879, 503)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1145, 311, 1179, 406)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1024, 293, 1074, 430)
# FPS: 15.76
# 3_newID 2
# 4_repeticion 2
# 7_cabron2
# 5_oldId 2
# 6_dIncrement[oldId] 1000
# 3_newID 4
# 4_repeticion 18
# 3_newID 8
# 4_repeticion 23
# 3_newID 9
# 4_repeticion 33
# 3_newID 1009
# 4_repeticion 26
# 3_newID 13
# 4_repeticion 25
# 3_newID 1013
# 4_repeticion 21
# 3_newID 2013
# 4_repeticion 14
# 3_newID 1004
# 4_repeticion 11
# 3_newID 2004
# 4_repeticion 1
# Frame #:  44
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_51_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1259, 284, 1335, 482)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (606, 279, 715, 592)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (873, 268, 997, 597)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1096, 297, 1134, 391)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (778, 281, 866, 514)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1142, 312, 1177, 408)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1018, 292, 1070, 433)
# FPS: 15.88
# 3_newID 2
# 4_repeticion 3
# 3_newID 4
# 4_repeticion 19
# 3_newID 8
# 4_repeticion 24
# 3_newID 9
# 4_repeticion 34
# 3_newID 1009
# 4_repeticion 27
# 3_newID 13
# 4_repeticion 26
# 3_newID 1013
# 4_repeticion 22
# 3_newID 2013
# 4_repeticion 15
# 3_newID 1004
# 4_repeticion 12
# 3_newID 2004
# 4_repeticion 2
# 5_oldId 4
# 6_dIncrement[oldId] 3000
# Frame #:  45
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_51_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1261, 284, 1335, 479)
# 1_1clave 2
# 1_2valor 1000
# 2_newId 1002
# Tracker ID: 1002, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (844, 283, 896, 432)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (596, 271, 712, 608)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (880, 271, 1009, 613)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1094, 290, 1135, 395)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (759, 276, 848, 517)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1139, 314, 1173, 408)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1012, 293, 1065, 435)
# FPS: 14.68
# 3_newID 2
# 4_repeticion 4
# 3_newID 4
# 4_repeticion 20
# 3_newID 8
# 4_repeticion 25
# 3_newID 9
# 4_repeticion 35
# 3_newID 1009
# 4_repeticion 28
# 3_newID 13
# 4_repeticion 27
# 3_newID 1013
# 4_repeticion 23
# 3_newID 2013
# 4_repeticion 16
# 3_newID 1004
# 4_repeticion 13
# 3_newID 2004
# 4_repeticion 3
# Frame #:  46
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_51_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1258, 284, 1333, 483)
# 1_1clave 2
# 1_2valor 1000
# 2_newId 1002
# Tracker ID: 1002, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (830, 285, 881, 433)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (602, 272, 720, 614)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (894, 269, 1028, 629)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1092, 289, 1134, 394)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (739, 277, 831, 530)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1136, 317, 1169, 410)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1010, 291, 1063, 433)
# FPS: 14.46
# 3_newID 2
# 4_repeticion 5
# 3_newID 4
# 4_repeticion 21
# 3_newID 8
# 4_repeticion 26
# 3_newID 9
# 4_repeticion 36
# 3_newID 1009
# 4_repeticion 29
# 3_newID 13
# 4_repeticion 28
# 3_newID 1013
# 4_repeticion 24
# 3_newID 2013
# 4_repeticion 17
# 3_newID 1004
# 4_repeticion 14
# 3_newID 2004
# 4_repeticion 4
# Frame #:  47
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_51_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1253, 281, 1333, 491)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (597, 276, 720, 634)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (905, 275, 1039, 639)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1090, 289, 1133, 397)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (726, 297, 812, 542)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1135, 319, 1168, 412)
# 2_newId 16
# Tracker ID: 16, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1006, 291, 1060, 435)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (845, 254, 962, 542)
# FPS: 5.60
# 3_newID 2
# 4_repeticion 6
# 3_newID 4
# 4_repeticion 22
# 3_newID 8
# 4_repeticion 27
# 3_newID 9
# 4_repeticion 37
# 3_newID 1009
# 4_repeticion 30
# 3_newID 13
# 4_repeticion 29
# 3_newID 1013
# 4_repeticion 25
# 3_newID 2013
# 4_repeticion 18
# 3_newID 1004
# 4_repeticion 15
# 3_newID 2004
# 4_repeticion 5
# 3_newID 1002
# 4_repeticion 1
# Frame #:  48
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1255, 282, 1334, 491)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (601, 262, 731, 644)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (918, 259, 1064, 663)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1096, 287, 1142, 403)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (705, 277, 798, 551)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1125, 309, 1162, 412)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (836, 247, 960, 556)
# FPS: 16.10
# 3_newID 2
# 4_repeticion 7
# 3_newID 4
# 4_repeticion 23
# 3_newID 8
# 4_repeticion 28
# 3_newID 9
# 4_repeticion 38
# 3_newID 1009
# 4_repeticion 31
# 3_newID 13
# 4_repeticion 30
# 3_newID 1013
# 4_repeticion 26
# 3_newID 2013
# 4_repeticion 19
# 3_newID 16
# 4_repeticion 1
# 3_newID 1004
# 4_repeticion 16
# 3_newID 2004
# 4_repeticion 6
# 3_newID 1002
# 4_repeticion 2
# 5_oldId 2
# 6_dIncrement[oldId] 2000
# Frame #:  49
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1262, 283, 1331, 463)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (614, 268, 749, 663)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (940, 259, 1090, 671)
# 1_1clave 9
# 1_2valor 2000
# 2_newId 2009
# Tracker ID: 2009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1096, 286, 1143, 405)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (694, 276, 791, 559)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1120, 307, 1158, 414)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (822, 251, 947, 561)
# FPS: 17.16
# 3_newID 2
# 4_repeticion 8
# 3_newID 4
# 4_repeticion 24
# 3_newID 8
# 4_repeticion 29
# 3_newID 9
# 4_repeticion 39
# 3_newID 1009
# 4_repeticion 32
# 3_newID 13
# 4_repeticion 31
# 3_newID 1013
# 4_repeticion 27
# 3_newID 2013
# 4_repeticion 20
# 3_newID 16
# 4_repeticion 2
# 7_cabron16
# 5_oldId 16
# 6_dIncrement[oldId] 1000
# 3_newID 1004
# 4_repeticion 17
# 3_newID 2004
# 4_repeticion 7
# 3_newID 1002
# 4_repeticion 3
# Frame #:  50
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1264, 284, 1327, 450)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (629, 260, 775, 686)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (968, 259, 1127, 695)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1117, 307, 1157, 416)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (814, 247, 943, 573)
# FPS: 16.51
# 3_newID 2
# 4_repeticion 9
# 3_newID 4
# 4_repeticion 25
# 3_newID 8
# 4_repeticion 30
# 3_newID 9
# 4_repeticion 40
# 3_newID 1009
# 4_repeticion 33
# 3_newID 13
# 4_repeticion 32
# 3_newID 1013
# 4_repeticion 28
# 3_newID 2013
# 4_repeticion 21
# 3_newID 2009
# 4_repeticion 1
# 3_newID 16
# 4_repeticion 3
# 3_newID 1004
# 4_repeticion 18
# 3_newID 2004
# 4_repeticion 8
# 3_newID 3013
# 4_repeticion 1
# 3_newID 1002
# 4_repeticion 4
# Frame #:  51
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1261, 284, 1325, 449)
# 1_1clave 4
# 1_2valor 3000
# 2_newId 3004
# Tracker ID: 3004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1000, 296, 1048, 420)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (654, 260, 803, 698)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1018, 255, 1181, 706)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (644, 264, 751, 586)
# 1_1clave 16
# 1_2valor 1000
# 2_newId 1016
# Tracker ID: 1016, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (948, 296, 1011, 469)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (818, 245, 950, 580)
# FPS: 15.75
# 3_newID 2
# 4_repeticion 10
# 3_newID 4
# 4_repeticion 26
# 3_newID 8
# 4_repeticion 31
# 3_newID 9
# 4_repeticion 41
# 3_newID 1009
# 4_repeticion 34
# 3_newID 13
# 4_repeticion 33
# 3_newID 15
# 4_repeticion 1
# 3_newID 1013
# 4_repeticion 29
# 3_newID 2013
# 4_repeticion 22
# 3_newID 2009
# 4_repeticion 2
# 5_oldId 9
# 6_dIncrement[oldId] 3000
# 3_newID 16
# 4_repeticion 4
# 3_newID 1004
# 4_repeticion 19
# 3_newID 2004
# 4_repeticion 9
# 3_newID 1002
# 4_repeticion 5
# Frame #:  52
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1261, 284, 1323, 445)
# 1_1clave 4
# 1_2valor 3000
# 2_newId 3004
# Tracker ID: 3004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1002, 299, 1050, 424)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (687, 267, 844, 727)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1079, 259, 1250, 722)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (636, 263, 745, 598)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1083, 289, 1126, 409)
# 1_1clave 16
# 1_2valor 1000
# 2_newId 1016
# Tracker ID: 1016, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (940, 309, 1000, 473)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (818, 245, 954, 592)
# FPS: 16.15
# 3_newID 2
# 4_repeticion 11
# 3_newID 4
# 4_repeticion 27
# 3_newID 8
# 4_repeticion 32
# 3_newID 9
# 4_repeticion 42
# 3_newID 1009
# 4_repeticion 35
# 3_newID 13
# 4_repeticion 34
# 3_newID 1013
# 4_repeticion 30
# 3_newID 2013
# 4_repeticion 23
# 3_newID 2009
# 4_repeticion 3
# 3_newID 16
# 4_repeticion 5
# 3_newID 1004
# 4_repeticion 20
# 3_newID 2004
# 4_repeticion 10
# 3_newID 1002
# 4_repeticion 6
# Frame #:  53
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_000_bodies.txt
# 1_1clave 4
# 1_2valor 3000
# 2_newId 3004
# Tracker ID: 3004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (999, 294, 1049, 429)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (729, 269, 896, 752)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1141, 251, 1325, 751)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (629, 258, 744, 613)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1079, 304, 1117, 411)
# 1_1clave 16
# 1_2valor 1000
# 2_newId 1016
# Tracker ID: 1016, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (923, 297, 990, 484)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (812, 244, 955, 607)
# FPS: 15.51
# 3_newID 1
# 4_repeticion 1
# 3_newID 2
# 4_repeticion 12
# 3_newID 4
# 4_repeticion 28
# 3_newID 8
# 4_repeticion 33
# 3_newID 9
# 4_repeticion 43
# 3_newID 1009
# 4_repeticion 36
# 3_newID 13
# 4_repeticion 35
# 3_newID 1013
# 4_repeticion 31
# 3_newID 2013
# 4_repeticion 24
# 3_newID 2009
# 4_repeticion 4
# 3_newID 16
# 4_repeticion 6
# 3_newID 1004
# 4_repeticion 21
# 3_newID 2004
# 4_repeticion 11
# 3_newID 1002
# 4_repeticion 7
# Frame #:  54
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1262, 281, 1324, 438)
# 1_1clave 2
# 1_2valor 2000
# 2_newId 2002
# Tracker ID: 2002, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (796, 293, 856, 467)
# 1_1clave 4
# 1_2valor 3000
# 2_newId 3004
# Tracker ID: 3004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (994, 288, 1048, 435)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (800, 273, 975, 779)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1158, 250, 1347, 764)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (620, 255, 739, 623)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1072, 291, 1112, 408)
# 1_1clave 16
# 1_2valor 1000
# 2_newId 1016
# Tracker ID: 1016, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (915, 298, 984, 489)
# FPS: 10.95
# 3_newID 2
# 4_repeticion 13
# 3_newID 4
# 4_repeticion 29
# 3_newID 8
# 4_repeticion 34
# 3_newID 9
# 4_repeticion 44
# 3_newID 1009
# 4_repeticion 37
# 3_newID 13
# 4_repeticion 36
# 3_newID 1013
# 4_repeticion 32
# 3_newID 2013
# 4_repeticion 25
# 3_newID 2009
# 4_repeticion 5
# 3_newID 16
# 4_repeticion 7
# 3_newID 1004
# 4_repeticion 22
# 3_newID 2004
# 4_repeticion 12
# 3_newID 1002
# 4_repeticion 8
# 3_newID 19
# 4_repeticion 1
# Frame #:  55
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1260, 281, 1324, 445)
# 1_1clave 2
# 1_2valor 2000
# 2_newId 2002
# Tracker ID: 2002, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (787, 290, 849, 471)
# 1_1clave 4
# 1_2valor 3000
# 2_newId 3004
# Tracker ID: 3004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (996, 289, 1050, 439)
# 2_newId 7
# Tracker ID: 7, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (810, 273, 990, 793)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (626, 262, 748, 646)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1067, 290, 1107, 408)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (836, 234, 988, 628)
# FPS: 15.72
# 3_newID 2
# 4_repeticion 14
# 3_newID 4
# 4_repeticion 30
# 3_newID 8
# 4_repeticion 35
# 3_newID 9
# 4_repeticion 45
# 3_newID 1009
# 4_repeticion 38
# 3_newID 13
# 4_repeticion 37
# 3_newID 1013
# 4_repeticion 33
# 3_newID 1008
# 4_repeticion 1
# 3_newID 2013
# 4_repeticion 26
# 3_newID 2009
# 4_repeticion 6
# 3_newID 16
# 4_repeticion 8
# 3_newID 1004
# 4_repeticion 23
# 3_newID 2004
# 4_repeticion 13
# 3_newID 1002
# 4_repeticion 9
# 3_newID 1016
# 4_repeticion 1
# Frame #:  56
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1260, 282, 1325, 448)
# 1_1clave 2
# 1_2valor 2000
# 2_newId 2002
# Tracker ID: 2002, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (779, 291, 842, 474)
# 1_1clave 4
# 1_2valor 3000
# 2_newId 3004
# Tracker ID: 3004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (990, 282, 1046, 442)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1084, 238, 1308, 843)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (654, 254, 787, 648)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (851, 234, 1008, 644)
# FPS: 13.44
# 3_newID 2
# 4_repeticion 15
# 3_newID 4
# 4_repeticion 31
# 3_newID 7
# 4_repeticion 1
# 3_newID 8
# 4_repeticion 36
# 3_newID 9
# 4_repeticion 46
# 3_newID 1009
# 4_repeticion 39
# 3_newID 13
# 4_repeticion 38
# 3_newID 15
# 4_repeticion 1
# 3_newID 1013
# 4_repeticion 34
# 3_newID 2013
# 4_repeticion 27
# 3_newID 2009
# 4_repeticion 7
# 3_newID 16
# 4_repeticion 9
# 3_newID 1004
# 4_repeticion 24
# 3_newID 2004
# 4_repeticion 14
# 3_newID 1002
# 4_repeticion 10
# 3_newID 1016
# 4_repeticion 2
# 5_oldId 16
# 6_dIncrement[oldId] 2000
# Frame #:  57
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1260, 282, 1324, 447)
# 1_1clave 4
# 1_2valor 3000
# 2_newId 3004
# Tracker ID: 3004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (990, 282, 1048, 445)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1159, 240, 1399, 890)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (668, 257, 812, 678)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1064, 301, 1106, 423)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (864, 233, 1029, 662)
# FPS: 15.97
# 3_newID 2
# 4_repeticion 16
# 3_newID 4
# 4_repeticion 32
# 3_newID 7
# 4_repeticion 2
# 7_cabron7
# 5_oldId 7
# 6_dIncrement[oldId] 1000
# 3_newID 8
# 4_repeticion 37
# 3_newID 9
# 4_repeticion 47
# 3_newID 1009
# 4_repeticion 40
# 3_newID 13
# 4_repeticion 39
# 3_newID 1013
# 4_repeticion 35
# 3_newID 2013
# 4_repeticion 28
# 3_newID 2009
# 4_repeticion 8
# 3_newID 16
# 4_repeticion 10
# 3_newID 1004
# 4_repeticion 25
# 3_newID 2004
# 4_repeticion 15
# 3_newID 1002
# 4_repeticion 11
# 3_newID 1016
# 4_repeticion 3
# 3_newID 2002
# 4_repeticion 1
# Frame #:  58
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1257, 286, 1320, 447)
# 1_1clave 8
# 1_2valor 1000
# 2_newId 1008
# Tracker ID: 1008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1172, 238, 1420, 909)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (700, 237, 858, 698)
# 2_newId 15
# Tracker ID: 15, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1060, 301, 1102, 425)
# 1_1clave 16
# 1_2valor 2000
# 2_newId 2016
# Tracker ID: 2016, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (873, 283, 954, 513)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (896, 222, 1070, 680)
# 2_newId 26
# Tracker ID: 26, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1706, 237, 1997, 871)
# FPS: 15.69
# 3_newID 2
# 4_repeticion 17
# 3_newID 4
# 4_repeticion 33
# 3_newID 7
# 4_repeticion 3
# 3_newID 8
# 4_repeticion 38
# 3_newID 9
# 4_repeticion 48
# 3_newID 1009
# 4_repeticion 41
# 3_newID 13
# 4_repeticion 40
# 3_newID 1013
# 4_repeticion 36
# 3_newID 2013
# 4_repeticion 29
# 3_newID 2009
# 4_repeticion 9
# 3_newID 16
# 4_repeticion 11
# 3_newID 1004
# 4_repeticion 26
# 3_newID 2004
# 4_repeticion 16
# 3_newID 1002
# 4_repeticion 12
# 3_newID 3004
# 4_repeticion 1
# 3_newID 1016
# 4_repeticion 4
# 3_newID 2002
# 4_repeticion 2
# 5_oldId 2
# 6_dIncrement[oldId] 3000
# Frame #:  59
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1258, 284, 1320, 443)
# 1_1clave 9
# 1_2valor 3000
# 2_newId 3009
# Tracker ID: 3009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1150, 291, 1173, 351)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (752, 244, 919, 724)
# 1_1clave 16
# 1_2valor 2000
# 2_newId 2016
# Tracker ID: 2016, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (864, 282, 947, 518)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (935, 219, 1116, 702)
# 2_newId 26
# Tracker ID: 26, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1645, 235, 1965, 937)
# FPS: 14.63
# 3_newID 2
# 4_repeticion 18
# 3_newID 4
# 4_repeticion 34
# 3_newID 7
# 4_repeticion 4
# 3_newID 8
# 4_repeticion 39
# 3_newID 9
# 4_repeticion 49
# 3_newID 1009
# 4_repeticion 42
# 3_newID 13
# 4_repeticion 41
# 3_newID 15
# 4_repeticion 1
# 3_newID 1013
# 4_repeticion 37
# 3_newID 1008
# 4_repeticion 1
# 3_newID 2013
# 4_repeticion 30
# 3_newID 2009
# 4_repeticion 10
# 3_newID 16
# 4_repeticion 12
# 3_newID 1004
# 4_repeticion 27
# 3_newID 2004
# 4_repeticion 17
# 3_newID 1002
# 4_repeticion 13
# 3_newID 3004
# 4_repeticion 2
# 5_oldId 4
# 6_dIncrement[oldId] 4000
# 3_newID 1016
# 4_repeticion 5
# 3_newID 2002
# 4_repeticion 3
# Frame #:  60
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1259, 283, 1321, 442)
# 1_1clave 2
# 1_2valor 3000
# 2_newId 3002
# Tracker ID: 3002, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (760, 290, 828, 493)
# 1_1clave 9
# 1_2valor 3000
# 2_newId 3009
# Tracker ID: 3009, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1153, 291, 1175, 348)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (820, 228, 999, 740)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (990, 215, 1180, 725)
# 2_newId 26
# Tracker ID: 26, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1658, 236, 1994, 973)
# FPS: 15.74
# 3_newID 2
# 4_repeticion 19
# 3_newID 4
# 4_repeticion 35
# 3_newID 7
# 4_repeticion 5
# 3_newID 8
# 4_repeticion 40
# 3_newID 9
# 4_repeticion 50
# 3_newID 1009
# 4_repeticion 43
# 3_newID 13
# 4_repeticion 42
# 3_newID 15
# 4_repeticion 2
# 7_cabron15
# 5_oldId 15
# 6_dIncrement[oldId] 1000
# 3_newID 1013
# 4_repeticion 38
# 3_newID 1008
# 4_repeticion 2
# 5_oldId 8
# 6_dIncrement[oldId] 2000
# 3_newID 2013
# 4_repeticion 31
# 3_newID 2009
# 4_repeticion 11
# 3_newID 16
# 4_repeticion 13
# 3_newID 1004
# 4_repeticion 28
# 3_newID 2004
# 4_repeticion 18
# 3_newID 1002
# 4_repeticion 14
# 3_newID 3004
# 4_repeticion 3
# 3_newID 1016
# 4_repeticion 6
# 3_newID 2002
# 4_repeticion 4
# 3_newID 2016
# 4_repeticion 1
# Frame #:  61
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_bodies.txt
# 2_newId 1
# Tracker ID: 1, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1259, 283, 1320, 440)
# 1_1clave 2
# 1_2valor 3000
# 2_newId 3002
# Tracker ID: 3002, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (754, 286, 826, 497)
# 1_1clave 7
# 1_2valor 1000
# 2_newId 1007
# Tracker ID: 1007, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (956, 246, 1149, 807)
# 1_1clave 13
# 1_2valor 3000
# 2_newId 3013
# Tracker ID: 3013, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (826, 225, 1011, 753)
# 1_1clave 16
# 1_2valor 2000
# 2_newId 2016
# Tracker ID: 2016, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (853, 305, 931, 530)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1059, 221, 1254, 746)
# FPS: 15.91
# 3_newID 2
# 4_repeticion 20
# 3_newID 4
# 4_repeticion 36
# 3_newID 7
# 4_repeticion 6
# 3_newID 8
# 4_repeticion 41
# 3_newID 9
# 4_repeticion 51
# 3_newID 1009
# 4_repeticion 44
# 3_newID 13
# 4_repeticion 43
# 3_newID 15
# 4_repeticion 3
# 3_newID 1013
# 4_repeticion 39
# 3_newID 1008
# 4_repeticion 3
# 3_newID 2013
# 4_repeticion 32
# 3_newID 2009
# 4_repeticion 12
# 3_newID 16
# 4_repeticion 14
# 3_newID 1004
# 4_repeticion 29
# 3_newID 2004
# 4_repeticion 19
# 3_newID 1002
# 4_repeticion 15
# 3_newID 3004
# 4_repeticion 4
# 3_newID 1016
# 4_repeticion 7
# 3_newID 2002
# 4_repeticion 5
# 3_newID 26
# 4_repeticion 1
# 3_newID 3009
# 4_repeticion 1
# Frame #:  62
# /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_bodies.txt
# 1_1clave 2
# 1_2valor 3000
# 2_newId 3002
# Tracker ID: 3002, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (752, 284, 827, 501)
# 1_1clave 4
# 1_2valor 4000
# 2_newId 4004
# Tracker ID: 4004, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (973, 282, 1040, 477)
# 1_1clave 7
# 1_2valor 1000
# 2_newId 1007
# Tracker ID: 1007, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1026, 219, 1246, 835)
# 1_1clave 8
# 1_2valor 2000
# 2_newId 2008
# Tracker ID: 2008, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1206, 217, 1424, 822)
# 1_1clave 15
# 1_2valor 1000
# 2_newId 1015
# Tracker ID: 1015, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1065, 328, 1106, 441)
# 1_1clave 16
# 1_2valor 2000
# 2_newId 2016
# Tracker ID: 2016, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (843, 306, 922, 534)
# 2_newId 19
# Tracker ID: 19, Class: person,  BBox Coords (xmin, ymin, xmax, ymax): (1074, 219, 1276, 763)
# FPS: 4.75
# 3_newID 1
# 4_repeticion 1
# 3_newID 2
# 4_repeticion 21
# 3_newID 4
# 4_repeticion 37
# 3_newID 7
# 4_repeticion 7
# 3_newID 8
# 4_repeticion 42
# 3_newID 9
# 4_repeticion 52
# 3_newID 1009
# 4_repeticion 45
# 3_newID 13
# 4_repeticion 44
# 3_newID 15
# 4_repeticion 4
# 3_newID 1013
# 4_repeticion 40
# 3_newID 1008
# 4_repeticion 4
# 3_newID 2013
# 4_repeticion 33
# 3_newID 2009
# 4_repeticion 13
# 3_newID 16
# 4_repeticion 15
# 3_newID 1004
# 4_repeticion 30
# 3_newID 2004
# 4_repeticion 20
# 3_newID 3013
# 4_repeticion 1
# 3_newID 1002
# 4_repeticion 16
# 3_newID 3004
# 4_repeticion 5
# 3_newID 1016
# 4_repeticion 8
# 3_newID 2002
# 4_repeticion 6
# 3_newID 26
# 4_repeticion 2
# 7_cabron26
# 5_oldId 26
# 6_dIncrement[oldId] 1000
# 3_newID 3009
# 4_repeticion 2
# 5_oldId 9
# 6_dIncrement[oldId] 4000

# %%
# Instalar dependencias insightface
# !pip uninstall -y mxnet && pip install mxnet-cu101
# !pip3 install insightface

# %%
cd "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython/"
# Out:
# /content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython

# %%
# Compilar pyx de cython, para obtener los .c
# !python3 setup.py install

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados sin crear imagenes recortadas, crea los txt de los box de las caras
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face_2.py"

# %%
# Ejecutar modelo de identificación de mascarilla con test propio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_ignacio.py"

# %%
# Ejecutar modelo de identificación de mascarilla con cuerpos recortados
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_body.py"

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados creando imagenes recortadas
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face.py"

# %%
# Ver imagen
from IPython.display import Image
Image("/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/images/cov_Salida_frame_10_19_32_400_4.jpg", width=500)

# %%
# Ejecutar modelo de identificación de mascarilla con test del repositorio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test.py"

# %%
# Ejecutar modelos de reidentificación
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/gamodel-r50/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r34-amf/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r50-am-lfw/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r100-ii/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-y1-test2/model, 0'
