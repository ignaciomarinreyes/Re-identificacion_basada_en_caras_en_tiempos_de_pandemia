# %%
# Ver características de la gráfica
# !nvidia-smi

# %%
# Montar Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort"
# Out:
# /content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort

# %%
# Instalar dependencias yolov4
# !pip3 install -r requirements.txt
# !python save_model.py --model yolov4

# %%
# Ejecutar yolov4
# !python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/object_tracker.py" --video ./data/video/test.mp4 --output ./outputs/demo.avi --model yolov4

# %%
# Instalar dependencias insightface
# !pip uninstall -y mxnet && pip install mxnet-cu101
# !pip3 install insightface

# %%
cd "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython/"
# Out:
# /content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython

# %%
# Compilar pyx de cython, para obtener los .c
# !python3 setup.py install

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados sin crear imagenes recortadas, crea los txt de los box de las caras
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face_2.py"
# Out:
# [11:51:55] ../src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v1.5.0. Attempting to upgrade...
# [11:51:55] ../src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_200_bodies.txt
# ===========================================
# 1 1262 283 69 180
# [11:51:59] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 7 614 268 135 395
# [11:52:01] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 2 faces
# Limit box: 685 281 36 48--->1 7
# Limit box: 713 277 23 28--->1 7
# ===========================================
# 1008 940 259 150 412
# [11:52:02] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 3 faces
# Limit box: 940 293 9 15--->1 1008
# Limit box: 1031 277 39 52--->1 1008
# Limit box: 1069 292 12 14--->0 1008
# ===========================================
# 2009 1096 286 47 119
# [11:52:04] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 1 faces
# Limit box: 1102 286 13 18--->1 2009
# ===========================================
# 3013 694 276 97 283
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 2 faces
# Limit box: 694 281 27 47--->1 3013
# Limit box: 716 280 16 21--->1 3013
# ===========================================
# 15 1120 307 38 107
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ===========================================
# 19 822 251 125 310
# [11:52:06] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 3 faces
# Limit box: 875 266 21 28--->1 19
# Limit box: 936 293 10 15--->0 19
# Limit box: 844 293 11 13--->1 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_400_bodies.txt
# ===========================================
# 1 1264 284 63 166
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 7 629 260 146 426
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# Limit box: 704 272 32 40--->1 7
# ===========================================
# 1008 968 259 159 436
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 3 faces
# Limit box: 1019 288 13 16--->1 1008
# Limit box: 1060 283 46 54--->1 1008
# Limit box: 974 301 15 19--->1 1008
# ===========================================
# 15 1117 307 40 109
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# Limit box: 1141 307 13 12--->1 15
# ===========================================
# 19 814 247 129 326
# [11:52:08] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 5 faces
# Limit box: 838 293 11 12--->0 19
# Limit box: 876 262 22 29--->1 19
# Limit box: 924 287 18 44--->1 19
# Limit box: 855 302 17 23--->0 19
# Limit box: 933 289 9 19--->1 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_600_bodies.txt
# ===========================================
# 1 1261 284 64 165
# [11:52:10] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 3004 1000 296 48 124
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 1 faces
# Limit box: 1000 296 24 29--->1 3004
# ===========================================
# 7 654 260 149 438
# [11:52:11] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 2 faces
# Limit box: 743 272 40 50--->1 7
# Limit box: 694 273 25 33--->1 7
# ===========================================
# 1008 1018 255 163 451
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# Limit box: 1019 285 13 15--->0 1008
# ===========================================
# 3013 644 264 107 322
# [11:52:13] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 20) (1, 6, 20, 20)
# (1, 4, 40, 40) (1, 6, 40, 40)
# (1, 4, 80, 80) (1, 6, 80, 80)
# find 0 faces
# ===========================================
# 1016 948 296 63 173
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# Limit box: 969 296 15 17--->1 1016
# ===========================================
# 19 818 245 132 335
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 3 faces
# Limit box: 872 260 23 29--->1 19
# Limit box: 831 296 12 15--->1 19
# Limit box: 931 294 15 19--->1 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_800_bodies.txt
# ===========================================
# 1 1261 284 62 161
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 3004 1002 299 48 125
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 1 faces
# Limit box: 1002 312 10 17--->1 3004
# ===========================================
# 7 687 267 157 460
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# Limit box: 796 286 42 53--->1 7
# ===========================================
# 1008 1079 259 171 463
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 3013 636 263 109 335
# [11:52:15] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 82, 80) (1, 6, 82, 80)
# find 2 faces
# Limit box: 656 281 31 48--->1 3013
# Limit box: 692 285 19 25--->1 3013
# ===========================================
# 15 1083 289 43 120
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# Limit box: 1093 289 15 13--->1 15
# ===========================================
# 1016 940 309 60 164
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 19 818 245 136 347
# [11:52:17] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 2 faces
# Limit box: 871 260 24 31--->1 19
# Limit box: 924 288 13 17--->1 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_000_bodies.txt
# ===========================================
# 3004 999 294 50 135
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 7 729 269 167 483
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 2 faces
# Limit box: 822 297 14 16--->1 7
# Limit box: 848 269 45 59--->1 7
# ===========================================
# 1008 1141 251 184 500
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 3013 629 258 115 355
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 42, 40) (1, 6, 42, 40)
# (1, 4, 83, 80) (1, 6, 83, 80)
# find 0 faces
# ===========================================
# 15 1079 304 38 107
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ===========================================
# 1016 923 297 67 187
# [11:52:19] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# Limit box: 943 297 16 20--->1 1016
# ===========================================
# 19 812 244 143 363
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 5 faces
# Limit box: 885 253 25 32--->1 19
# Limit box: 847 270 45 59--->1 19
# Limit box: 823 296 13 17--->1 19
# Limit box: 943 295 11 21--->1 19
# Limit box: 938 285 11 12--->0 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_bodies.txt
# ===========================================
# 1 1262 281 62 157
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ===========================================
# 2002 796 293 60 174
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# Limit box: 815 293 13 15--->1 2002
# ===========================================
# 3004 994 288 54 147
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# Limit box: 1008 288 14 16--->1 3004
# ===========================================
# 7 800 273 175 506
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 2 faces
# Limit box: 815 291 14 18--->1 7
# Limit box: 895 273 31 24--->1 7
# ===========================================
# 1008 1158 250 189 514
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 3013 620 255 119 368
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 82, 80) (1, 6, 82, 80)
# find 0 faces
# ===========================================
# 15 1072 291 40 117
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 1 faces
# Limit box: 1089 291 12 9--->0 15
# ===========================================
# 1016 915 298 69 191
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_bodies.txt
# ===========================================
# 1 1260 281 64 164
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 2002 787 290 62 181
# [11:52:22] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 2 faces
# Limit box: 810 295 14 16--->1 2002
# Limit box: 796 294 11 15--->1 2002
# ===========================================
# 3004 996 289 54 150
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# Limit box: 1008 291 14 18--->1 3004
# ===========================================
# 7 810 273 180 520
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 3 faces
# Limit box: 810 294 14 19--->0 7
# Limit box: 902 408 28 32--->0 7
# Limit box: 881 384 47 61--->0 7
# ===========================================
# 3013 626 262 122 384
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 42, 40) (1, 6, 42, 40)
# (1, 4, 84, 80) (1, 6, 84, 80)
# find 0 faces
# ===========================================
# 15 1067 290 40 118
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# ===========================================
# 19 836 234 152 394
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# Limit box: 903 241 35 43--->1 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_bodies.txt
# ===========================================
# 1 1260 282 65 166
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 2002 779 291 63 183
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# Limit box: 808 296 14 17--->1 2002
# ===========================================
# 3004 990 282 56 160
# [11:52:25] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# Limit box: 1001 287 13 14--->1 3004
# ===========================================
# 1008 1084 238 224 605
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 3013 654 254 133 394
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# ===========================================
# 19 851 234 157 410
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 2 faces
# Limit box: 998 287 9 14--->0 19
# Limit box: 926 251 37 45--->1 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_bodies.txt
# ===========================================
# 1 1260 282 64 165
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 3004 990 282 58 163
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ===========================================
# 1008 1159 240 240 650
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 3013 668 257 144 421
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# Limit box: 800 291 11 18--->0 3013
# ===========================================
# 15 1064 301 42 122
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ===========================================
# 19 864 233 165 429
# [11:52:28] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 2 faces
# Limit box: 966 243 39 48--->1 19
# Limit box: 902 286 14 19--->1 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_bodies.txt
# ===========================================
# 1 1257 286 63 161
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ===========================================
# 1008 1172 238 248 671
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 3013 700 237 158 461
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 0 faces
# ===========================================
# 15 1060 301 42 124
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# ===========================================
# 2016 873 283 81 230
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 2 faces
# Limit box: 902 301 17 21--->1 2016
# Limit box: 921 283 12 13--->1 2016
# ===========================================
# 19 896 222 174 458
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 1 faces
# Limit box: 921 283 11 13--->0 19
# ===========================================
# 26 1706 237 291 634
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_bodies.txt
# ===========================================
# 1 1258 284 62 159
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 3009 1150 291 23 60
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 3013 752 244 167 480
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 2 faces
# Limit box: 789 291 16 19--->1 3013
# Limit box: 831 298 11 15--->1 3013
# ===========================================
# 2016 864 282 83 236
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ===========================================
# 19 935 219 181 483
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 1 faces
# Limit box: 994 286 15 17--->0 19
# ===========================================
# 26 1645 235 320 702
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_bodies.txt
# ===========================================
# 1 1259 283 62 159
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 3002 760 290 68 203
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 1 faces
# Limit box: 783 299 16 19--->1 3002
# ===========================================
# 3009 1153 291 22 57
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 3013 820 228 179 512
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# Limit box: 876 301 23 30--->1 3013
# ===========================================
# 19 990 215 190 510
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 26 1658 236 336 737
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_bodies.txt
# ===========================================
# 1 1259 283 61 157
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 3002 754 286 72 211
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 2 faces
# Limit box: 798 297 12 13--->1 3002
# Limit box: 772 295 16 19--->1 3002
# ===========================================
# 1007 956 246 193 561
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# Limit box: 993 286 16 19--->0 1007
# ===========================================
# 3013 826 225 185 528
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 5 faces
# Limit box: 994 286 16 20--->1 3013
# Limit box: 903 282 13 17--->0 3013
# Limit box: 908 327 18 25--->0 3013
# Limit box: 875 294 20 26--->1 3013
# Limit box: 970 308 16 20--->0 3013
# ===========================================
# 2016 853 305 78 225
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 1 faces
# Limit box: 878 354 28 25--->0 2016
# ===========================================
# 19 1059 221 195 525
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_bodies.txt
# ===========================================
# 3002 752 284 75 217
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 3 faces
# Limit box: 793 296 12 14--->1 3002
# Limit box: 765 296 16 19--->1 3002
# Limit box: 818 301 8 16--->1 3002
# ===========================================
# 4004 973 282 67 195
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# Limit box: 991 289 14 18--->1 4004
# ===========================================
# 1007 1026 219 220 616
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ===========================================
# 2008 1206 217 218 605
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ===========================================
# 1015 1065 328 41 113
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ===========================================
# 2016 843 306 79 228
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 1 faces
# Limit box: 865 306 21 21--->1 2016
# ===========================================
# 19 1074 219 202 544
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 3 faces
# Limit box: 1218 235 57 76--->1 19
# Limit box: 1097 276 14 16--->0 19
# Limit box: 1173 294 53 73--->1 19

# %%
# Ejecutar modelo de identificación de mascarilla con test propio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_ignacio.py"

# %%
# Ejecutar modelo de identificación de mascarilla con cuerpos recortados
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_body.py"

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados creando imagenes recortadas
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face.py"

# %%
# Ver imagen
from IPython.display import Image
Image("/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/images/cov_Salida_frame_10_19_32_400_4.jpg", width=500)

# %%
# Ejecutar modelo de identificación de mascarilla con test del repositorio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test.py"

# %%
# Ejecutar modelos de reidentificación
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/gamodel-r50/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r34-amf/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r50-am-lfw/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r100-ii/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-y1-test2/model, 0'

# %%
#Instalar dependencias deepFace
# !pip3 install deepFace

# %%
#DeepFace
# !python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py"
