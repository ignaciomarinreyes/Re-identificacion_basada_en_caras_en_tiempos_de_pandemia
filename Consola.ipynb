# %%
# Ver características de la gráfica
# !nvidia-smi

# %%
# Montar Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort"
# Out:
# /content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort

# %%
# Instalar dependencias yolov4
# !pip3 install -r requirements.txt
# !python save_model.py --model yolov4

# %%
# Ejecutar yolov4
# !python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/object_tracker.py" --video ./data/video/test.mp4 --output ./outputs/demo.avi --model yolov4

# %%
# Instalar dependencias insightface
# !pip uninstall -y mxnet && pip install mxnet-cu101
# !pip3 install insightface

# %%
cd "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython/"
# Out:
# /content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython

# %%
# Compilar pyx de cython, para obtener los .c
# !python3 setup.py install

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados sin crear imagenes recortadas, crea los txt de los box de las caras
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face_2.py"
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_result.txt
# ===========================================
# 834 289 55 155 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# 0 [ 8  4 28 22] 0.86457205
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_result.txt
# ===========================================
# 1084 238 224 605 27
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_result.txt
# ===========================================
# 1260 282 65 166 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_result.txt
# ===========================================
# 851 234 157 410 38
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 2 faces
# 0 [147  53 156  67] 0.060801998
# 1 [ 75  17 112  62] 0.9810884
# Limit box: 926 251 37 45--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_bodies.txt
# ===========================================
# 1064 301 42 122 1
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_result.txt
# ===========================================
# 1155 296 20 48 9
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_result.txt
# ===========================================
# 991 280 57 163 13
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# 0 [ 3 34 12 46] 0.61753863
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_result.txt
# ===========================================
# 668 257 142 420 16
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_result.txt
# ===========================================
# 826 290 56 157 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# 0 [ 7  2 18 17] 0.84409994
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_result.txt
# ===========================================
# 1159 240 240 650 27
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_result.txt
# ===========================================
# 1260 282 64 165 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_result.txt
# ===========================================
# 864 233 165 429 38
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 2 faces
# 0 [102  10 141  58] 0.9365115
# Limit box: 966 243 39 48--->1
# 1 [38 53 52 72] 0.7913142
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_bodies.txt
# ===========================================
# 1060 301 42 124 1
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_result.txt
# ===========================================
# 1154 297 21 49 9
#
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 105) (1, 6, 80, 105)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_result.txt
# ===========================================
# 700 237 156 461 16
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_result.txt
# ===========================================
# 872 283 82 230 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 2 faces
# 0 [31 18 48 39] 0.84157056
# 1 [49  0 61 13] 0.9661568
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_result.txt
# ===========================================
# 1172 238 247 671 27
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_result.txt
# ===========================================
# 1257 286 63 161 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_result.txt
# ===========================================
# 896 222 174 458 38
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 1 faces
# 0 [25 61 36 74] 0.049892504
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_result.txt
# ===========================================
# 1706 237 291 634 42
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_bodies.txt
# ===========================================
# 1153 293 22 54 9
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_result.txt
# ===========================================
# 752 244 165 479 16
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [37 47 53 67] 0.67854834
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_result.txt
# ===========================================
# 863 282 85 236 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 1 faces
# 0 [54  3 65 17] 0.81825703
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_result.txt
# ===========================================
# 1110 283 33 82 20
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_result.txt
# ===========================================
# 1258 284 62 159 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_result.txt
# ===========================================
# 935 219 181 483 38
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 1 faces
# 0 [59 67 74 84] 0.10312002
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_result.txt
# ===========================================
# 1645 235 320 702 42
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_bodies.txt
# ===========================================
# 761 290 66 203 2
#
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 82, 80) (1, 6, 82, 80)
# find 1 faces
# 0 [22  9 38 27] 0.9931271
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_result.txt
# ===========================================
# 1153 293 22 54 9
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_result.txt
# ===========================================
# 820 228 178 512 16
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 1 faces
# 0 [ 56  73  79 103] 0.6812399
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_result.txt
# ===========================================
# 1110 283 33 80 20
#
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_result.txt
# ===========================================
# 801 292 60 169 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_result.txt
# ===========================================
# 1259 283 62 159 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_result.txt
# ===========================================
# 990 215 190 510 38
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_result.txt
# ===========================================
# 1658 236 336 737 42
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_bodies.txt
# ===========================================
# 755 286 71 211 2
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 2 faces
# 0 [43 11 55 24] 0.9929495
# 1 [17  9 33 28] 0.98512125
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_result.txt
# ===========================================
# 957 246 192 561 3
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 2 faces
# 0 [37 40 53 59] 0.22485127
# 1 [13 61 29 81] 0.0068452726
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_result.txt
# ===========================================
# 825 225 183 527 16
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 4 faces
# 0 [79 57 91 73] 0.08660333
# 1 [51 67 71 92] 0.5677627
# 2 [ 83 103 101 127] 0.0037346664
# 3 [169  62 182  80] 0.61914104
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_result.txt
# ===========================================
# 853 305 79 225 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# 0 [25 49 53 74] 0.14481731
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_result.txt
# ===========================================
# 793 293 61 171 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [ 5  4 16 17] 0.9894537
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_result.txt
# ===========================================
# 1259 283 61 157 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_result.txt
# ===========================================
# 1059 221 195 525 38
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_bodies.txt
# ===========================================
# 1065 328 41 113 1
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_result.txt
# ===========================================
# 752 284 75 217 2
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 3 faces
# 0 [41 12 53 26] 0.98965466
# 1 [13 12 29 31] 0.9956351
# 2 [66 17 74 33] 0.25487253
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_result.txt
# ===========================================
# 1026 219 220 616 3
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_result.txt
# ===========================================
# 974 282 66 194 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [17  8 32 25] 0.9840321
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_result.txt
# ===========================================
# 843 306 79 228 19
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 1 faces
# 0 [22  0 43 21] 0.8449508
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_result.txt
# ===========================================
# 790 306 52 148 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_result.txt
# ===========================================
# 1206 217 218 605 27
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_result.txt
# ===========================================
# 1074 219 202 544 38
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 3 faces
# 0 [144  16 201  92] 0.87629765
# Limit box: 1218 235 57 76--->1
# 1 [23 57 37 73] 0.027901484
# 2 [ 99  75 152 148] 0.3920755
# Limit box: 1173 294 53 73--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_000_bodies.txt
# ===========================================
# 1059 322 48 127 1
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 1 faces
# 0 [25  3 39 23] 0.40295273
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_000_result.txt
# ===========================================
# 734 290 76 218 2
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 3 faces
# 0 [55  9 66 22] 0.9814773
# 1 [25 10 43 29] 0.9887475
# 2 [67  7 75 22] 0.41124696
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_000_result.txt
# ===========================================
# 1047 215 225 631 3
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [30 73 45 91] 0.10073897
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_000_result.txt
# ===========================================
# 1151 290 25 61 9
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_000_result.txt
# ===========================================
# 971 291 64 189 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 2 faces
# 0 [14  4 28 21] 0.32325098
# 1 [39  0 63 15] 0.32178006
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_000_result.txt
# ===========================================
# 821 302 90 251 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 2 faces
# 0 [26  0 48 25] 0.67108804
# 1 [54  0 70 17] 0.9710833
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_000_result.txt
# ===========================================
# 1110 285 32 78 20
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_000_result.txt
# ===========================================
# 782 308 53 148 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_000_result.txt
# ===========================================
# 1237 218 236 651 27
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# 0 [217  45 235  69] 0.018029809
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_000_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_200_bodies.txt
# ===========================================
# 1052 310 55 146 1
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_200_result.txt
# ===========================================
# 727 285 79 227 2
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 2 faces
# 0 [19  6 37 26] 0.96481174
# 1 [62 17 76 35] 0.8196996
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_200_result.txt
# ===========================================
# 1151 289 25 63 9
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_200_result.txt
# ===========================================
# 965 282 69 204 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 1 faces
# 0 [23  4 38 22] 0.49620485
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_200_result.txt
# ===========================================
# 809 292 96 270 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 2 faces
# 0 [64  0 80 19] 0.9722721
# 1 [37  0 59 29] 0.9121916
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_200_result.txt
# ===========================================
# 1109 303 29 70 20
#
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 101) (1, 6, 80, 101)
# find 1 faces
# 0 [ 9  0 18 13] 0.68859375
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_200_result.txt
# ===========================================
# 1250 216 242 664 27
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_200_result.txt
# ===========================================
# 1414 210 324 704 42
#
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 56) (1, 6, 40, 56)
# (1, 4, 80, 111) (1, 6, 80, 111)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_200_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_400_bodies.txt
# ===========================================
# 1047 308 59 157 1
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 1 faces
# 0 [19 18 52 51] 0.62363666
# Limit box: 1066 326 33 33--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_400_result.txt
# ===========================================
# 723 292 78 222 2
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 3 faces
# 0 [47  9 58 24] 0.86537737
# 1 [10  9 29 32] 0.9751109
# 2 [60  5 74 22] 0.8811078
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_400_result.txt
# ===========================================
# 1149 289 25 63 9
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_400_result.txt
# ===========================================
# 965 293 67 196 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [20  0 37 22] 0.9616018
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_400_result.txt
# ===========================================
# 802 297 97 273 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [41  5 65 36] 0.9008529
# Limit box: 843 302 24 31--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_400_result.txt
# ===========================================
# 1108 303 32 78 20
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_400_result.txt
# ===========================================
# 1534 191 337 737 42
#
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 55) (1, 6, 40, 55)
# (1, 4, 80, 110) (1, 6, 80, 110)
# find 1 faces
# 0 [221  30 266  82] 0.012079257
# Limit box: 1755 221 45 52--->0
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_400_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_600_bodies.txt
# ===========================================
# 1043 321 57 149 1
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# 0 [24 13 42 35] 0.96060795
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_600_result.txt
# ===========================================
# 698 289 83 236 2
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 2 faces
# 0 [28  4 47 26] 0.98964906
# 1 [ 0 32 19 66] 0.62612945
# Limit box: 698 321 19 34--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_600_result.txt
# ===========================================
# 1147 291 24 60 9
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_600_result.txt
# ===========================================
# 960 295 68 202 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 1 faces
# 0 [16  0 34 18] 0.96635944
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_600_result.txt
# ===========================================
# 796 288 105 299 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 2 faces
# 0 [36  3 58 32] 0.6387885
# 1 [ 91   0 104  14] 0.9741778
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_600_result.txt
# ===========================================
# 1105 298 36 87 20
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_600_result.txt
# ===========================================
# 740 299 67 188 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_600_result.txt
# ===========================================
# 1529 186 345 754 42
#
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 55) (1, 6, 40, 55)
# (1, 4, 80, 110) (1, 6, 80, 110)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_600_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_800_bodies.txt
# ===========================================
# 1035 316 62 162 1
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_800_result.txt
# ===========================================
# 688 297 80 237 2
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 81) (1, 6, 80, 81)
# find 1 faces
# 0 [27  0 48 25] 0.9861144
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_800_result.txt
# ===========================================
# 1146 289 24 62 9
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_800_result.txt
# ===========================================
# 956 289 73 214 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [21  0 40 19] 0.978303
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_800_result.txt
# ===========================================
# 788 292 108 303 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [48  6 75 41] 0.7052955
# Limit box: 836 298 27 35--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_800_result.txt
# ===========================================
# 1104 294 38 93 20
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_800_result.txt
# ===========================================
# 734 302 67 186 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_800_result.txt
# ===========================================
# 1248 282 60 154 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_55_800_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_000_bodies.txt
# ===========================================
# 1030 315 65 171 1
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_000_result.txt
# ===========================================
# 680 303 82 237 2
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [20  0 41 24] 0.96375173
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_000_result.txt
# ===========================================
# 1145 289 25 62 9
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_000_result.txt
# ===========================================
# 956 293 73 212 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 1 faces
# 0 [22  2 41 25] 0.96233976
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_000_result.txt
# ===========================================
# 792 290 114 317 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 2 faces
# 0 [67 11 94 49] 0.9417961
# Limit box: 859 301 27 38--->1
# 1 [43  3 61 27] 0.96196634
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_000_result.txt
# ===========================================
# 1107 298 36 89 20
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 1 faces
# 0 [ 5  0 25 17] 0.8843847
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_000_result.txt
# ===========================================
# 726 301 66 181 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_000_result.txt
# ===========================================
# 1249 284 58 151 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_000_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_200_bodies.txt
# ===========================================
# 1021 306 71 188 1
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_200_result.txt
# ===========================================
# 657 293 88 259 2
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 2 faces
# 0 [40  0 62 29] 0.7824843
# 1 [ 2  0 34 28] 0.9379193
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_200_result.txt
# ===========================================
# 1144 287 26 65 9
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_200_result.txt
# ===========================================
# 951 284 80 237 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 81) (1, 6, 80, 81)
# find 1 faces
# 0 [18  6 37 27] 0.8814314
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_200_result.txt
# ===========================================
# 799 290 108 301 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 3 faces
# 0 [23  0 43 27] 0.9901404
# 1 [ 72   4 100  42] 0.96532893
# Limit box: 871 294 28 38--->1
# 2 [46 37 66 61] 0.3434046
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_200_result.txt
# ===========================================
# 1106 291 39 96 20
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_200_result.txt
# ===========================================
# 719 304 68 191 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_200_result.txt
# ===========================================
# 1248 284 58 149 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_200_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_400_bodies.txt
# ===========================================
# 1011 294 77 208 1
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 1 faces
# 0 [27  1 41 18] 0.83537626
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_400_result.txt
# ===========================================
# 646 292 92 269 2
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 1 faces
# 0 [43 12 64 36] 0.95520115
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_400_result.txt
# ===========================================
# 1143 284 26 69 9
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_400_result.txt
# ===========================================
# 943 279 86 255 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 81) (1, 6, 80, 81)
# find 1 faces
# 0 [26 11 45 33] 0.9396277
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_400_result.txt
# ===========================================
# 823 295 119 336 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# 0 [ 74  12 109  56] 0.9939646
# Limit box: 897 307 35 44--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_400_result.txt
# ===========================================
# 1105 288 40 100 20
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_400_result.txt
# ===========================================
# 712 302 69 197 21
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_400_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_600_bodies.txt
# ===========================================
# 1006 293 79 214 1
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 2 faces
# 0 [66 25 78 54] 0.063705936
# 1 [25 13 38 28] 0.8904812
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_600_result.txt
# ===========================================
# 644 297 91 265 2
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 2 faces
# 0 [74  8 90 30] 0.95892394
# 1 [28  0 50 22] 0.97430044
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_600_result.txt
# ===========================================
# 1144 285 26 68 9
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_600_result.txt
# ===========================================
# 940 278 89 262 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 1 faces
# 0 [17 13 57 61] 0.96318936
# Limit box: 957 291 40 48--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_600_result.txt
# ===========================================
# 854 285 134 373 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 2 faces
# 0 [76  5 88 19] 0.19932884
# 1 [100   2 133  59] 0.9719024
# Limit box: 954 287 33 57--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_600_result.txt
# ===========================================
# 1106 288 39 102 20
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 1 faces
# 0 [0 0 7 9] 0.40215495
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_600_result.txt
# ===========================================
# 703 302 70 202 21
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 2 faces
# 0 [15  5 31 23] 0.93212134
# 1 [33  0 46 14] 0.7929864
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_600_result.txt
# ===========================================
# 1248 285 57 147 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_600_result.txt
# ===========================================
# 771 291 76 258 49
#
# (1, 4, 23, 20) (1, 6, 23, 20)
# (1, 4, 46, 40) (1, 6, 46, 40)
# (1, 4, 91, 80) (1, 6, 91, 80)
# find 1 faces
# 0 [33  0 55 28] 0.88518924
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_600_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_800_bodies.txt
# ===========================================
# 633 287 97 285 2
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 3 faces
# 0 [81 10 96 32] 0.9692308
# 1 [30 10 52 36] 0.9834747
# 2 [23 31 57 70] 0.2457202
# Limit box: 656 318 34 39--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_800_result.txt
# ===========================================
# 1143 283 28 73 9
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_800_result.txt
# ===========================================
# 906 285 144 398 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 2 faces
# 0 [57  0 78 25] 0.95781535
# 1 [15  1 26 14] 0.30872834
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_800_result.txt
# ===========================================
# 1106 288 39 101 20
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_800_result.txt
# ===========================================
# 685 277 81 236 21
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 2 faces
# 0 [29 20 45 41] 0.99743265
# 1 [29 62 40 77] 0.053199623
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_800_result.txt
# ===========================================
# 1248 283 57 148 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_800_result.txt
# ===========================================
# 769 296 77 258 49
#
# [21:57:05] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 23, 20) (1, 6, 23, 20)
# (1, 4, 45, 40) (1, 6, 45, 40)
# (1, 4, 90, 80) (1, 6, 90, 80)
# find 1 faces
# 0 [32  0 54 30] 0.96327907
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_56_800_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_000_bodies.txt
# ===========================================
# 611 281 104 309 2
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 81) (1, 6, 80, 81)
# find 2 faces
# 0 [46  9 70 38] 0.9865361
# 1 [ 90  24 103  44] 0.31527126
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_000_result.txt
# ===========================================
# 1142 283 29 74 9
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_000_result.txt
# ===========================================
# 929 284 94 279 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 81) (1, 6, 80, 81)
# find 2 faces
# 0 [31  6 52 31] 0.94259435
# 1 [78 13 93 35] 0.70105135
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_000_result.txt
# ===========================================
# 909 284 148 411 19
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 4 faces
# 0 [ 6  6 18 20] 0.048288677
# 1 [50  4 73 33] 0.98405325
# 2 [106   0 129  21] 0.8723556
# 3 [ 63  86 123 136] 0.08994863
# Limit box: 972 370 60 50--->0
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_000_result.txt
# ===========================================
# 1106 288 39 102 20
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_000_result.txt
# ===========================================
# 679 274 82 249 21
#
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 81, 80) (1, 6, 81, 80)
# find 1 faces
# 0 [24 30 41 52] 0.99206513
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_000_result.txt
# ===========================================
# 1019 278 173 470 27
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 2 faces
# 0 [35  0 50 15] 0.26232255
# 1 [ 72  13 125  92] 0.80472904
# Limit box: 1091 291 53 79--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_000_result.txt
# ===========================================
# 1248 285 56 146 32
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_000_result.txt
# ===========================================
# 764 287 85 285 49
#
# (1, 4, 23, 20) (1, 6, 23, 20)
# (1, 4, 45, 40) (1, 6, 45, 40)
# (1, 4, 90, 80) (1, 6, 90, 80)
# find 1 faces
# 0 [29  0 52 32] 0.9563796
# Limit box: 793 287 23 32--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_000_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_200_bodies.txt
# ===========================================
# 601 278 106 323 2
#
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 81, 80) (1, 6, 81, 80)
# find 2 faces
# 0 [40  9 65 37] 0.96322906
# 1 [ 85  25 102  46] 0.99710244
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_200_result.txt
# ===========================================
# 924 278 100 296 13
#
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 2 faces
# 0 [44  9 66 37] 0.9542303
# 1 [81 23 97 43] 0.7495463
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_200_result.txt
# ===========================================
# 1104 288 40 104 20
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_200_result.txt
# ===========================================
# 672 291 74 227 21
#
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 82, 80) (1, 6, 82, 80)
# find 2 faces
# 0 [33 11 46 27] 0.7398077
# 1 [14 13 31 33] 0.99408615
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_200_result.txt
# ===========================================
# 1086 285 168 440 27
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_200_result.txt
# ===========================================
# 1248 286 55 144 32
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_200_result.txt
# ===========================================
# 759 284 88 295 49
#
# (1, 4, 23, 20) (1, 6, 23, 20)
# (1, 4, 45, 40) (1, 6, 45, 40)
# (1, 4, 90, 80) (1, 6, 90, 80)
# find 1 faces
# 0 [35  1 59 34] 0.9945338
# Limit box: 794 285 24 33--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_200_result.txt
# ===========================================
# 844 291 53 176 53
#
# (1, 4, 22, 20) (1, 6, 22, 20)
# (1, 4, 44, 40) (1, 6, 44, 40)
# (1, 4, 88, 80) (1, 6, 88, 80)
# find 1 faces
# 0 [16  0 30 12] 0.88884217
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_200_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_57_400_bodies.txt
# ===========================================
# 1002 278 82 229 1
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 2 faces
# 0 [16  6 35 33] 0.95341146
# ...
# ===========================================
# 672 255 154 405 58
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 1 faces
# 0 [ 83  16 114  53] 0.971503
# Limit box: 755 271 31 37--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_000_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_200_bodies.txt
# ===========================================
# 1134 297 42 115 9
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_200_result.txt
# ===========================================
# 1492 248 331 707 13
#
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 57) (1, 6, 40, 57)
# (1, 4, 80, 113) (1, 6, 80, 113)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_200_result.txt
# ===========================================
# 1717 290 265 692 19
#
# (1, 4, 23, 20) (1, 6, 23, 20)
# (1, 4, 46, 40) (1, 6, 46, 40)
# (1, 4, 91, 80) (1, 6, 91, 80)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_200_result.txt
# ===========================================
# 973 252 111 312 20
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [49 21 71 48] 0.038590185
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_200_result.txt
# ===========================================
# 1121 219 210 572 38
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_200_result.txt
# ===========================================
# 682 258 161 422 58
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 1 faces
# 0 [ 87  17 124  64] 0.9726043
# Limit box: 769 275 37 47--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_200_result.txt
# ===========================================
# 1093 296 40 99 71
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 1 faces
# 0 [14 15 26 31] 0.40586036
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_200_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_400_bodies.txt
# ===========================================
# 1261 202 258 632 1
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_400_result.txt
# ===========================================
# 1131 299 42 116 9
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_400_result.txt
# ===========================================
# 1740 296 267 695 19
#
# (1, 4, 26, 20) (1, 6, 26, 20)
# (1, 4, 52, 40) (1, 6, 52, 40)
# (1, 4, 103, 80) (1, 6, 103, 80)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_400_result.txt
# ===========================================
# 969 256 116 324 20
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_400_result.txt
# ===========================================
# 1136 217 217 591 38
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [ 9 75 19 87] 0.006490954
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_400_result.txt
# ===========================================
# 712 251 168 439 58
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 2 faces
# 0 [103   7 146  58] 0.96820575
# Limit box: 815 258 43 51--->1
# 1 [122   0 146  23] 0.044529583
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_400_result.txt
# ===========================================
# 1091 295 40 102 71
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_400_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_600_bodies.txt
# ===========================================
# 1385 203 258 639 1
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_600_result.txt
# ===========================================
# 1129 297 42 118 9
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_600_result.txt
# ===========================================
# 973 249 124 341 20
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 2 faces
# 0 [37 60 47 72] 0.14483073
# 1 [52 24 77 53] 0.065678276
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_600_result.txt
# ===========================================
# 746 254 178 461 58
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 1 faces
# 0 [125  23 166  75] 0.9673411
# Limit box: 871 277 41 52--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_600_result.txt
# ===========================================
# 1089 295 41 104 71
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 2 faces
# 0 [13 17 24 32] 0.8116716
# 1 [ 0 10  4 16] 0.06626529
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_600_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_800_bodies.txt
# ===========================================
# 1405 200 258 642 1
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_800_result.txt
# ===========================================
# 1125 290 45 123 9
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 1 faces
# 0 [11  7 19 18] 0.43080282
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_800_result.txt
# ===========================================
# 1616 169 280 684 19
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_800_result.txt
# ===========================================
# 976 252 126 349 20
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 3 faces
# 0 [70 66 80 78] 0.052984063
# 1 [48 28 74 59] 0.111957416
# Limit box: 1024 280 26 31--->0
# 2 [117  60 125  72] 0.012651464
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_800_result.txt
# ===========================================
# 788 236 195 506 58
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# 0 [131  20 178  77] 0.9020743
# Limit box: 919 256 47 57--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_05_800_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_000_bodies.txt
# ===========================================
# 1122 290 47 129 9
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_000_result.txt
# ===========================================
# 1622 161 282 686 19
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_000_result.txt
# ===========================================
# 972 251 129 357 20
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_000_result.txt
# ===========================================
# 1764 168 207 709 57
#
# (1, 4, 31, 20) (1, 6, 31, 20)
# (1, 4, 61, 40) (1, 6, 61, 40)
# (1, 4, 121, 80) (1, 6, 121, 80)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_000_result.txt
# ===========================================
# 857 238 202 525 58
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_000_result.txt
# ===========================================
# 1079 291 42 107 71
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 1 faces
# 0 [14 17 28 34] 0.85422724
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_000_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_200_bodies.txt
# ===========================================
# 973 275 56 154 2
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_200_result.txt
# ===========================================
# 1121 289 47 132 9
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_200_result.txt
# ===========================================
# 1811 164 209 719 57
#
# [21:57:47] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 16) (1, 6, 34, 16)
# (1, 4, 68, 31) (1, 6, 68, 31)
# (1, 4, 135, 62) (1, 6, 135, 62)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_200_result.txt
# ===========================================
# 926 238 224 581 58
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# 0 [130  34 163  77] 0.051791087
# Limit box: 1056 272 33 43--->0
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_200_result.txt
# ===========================================
# 1077 291 42 109 71
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_200_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_400_bodies.txt
# ===========================================
# 976 283 53 145 2
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_400_result.txt
# ===========================================
# 996 237 145 405 20
#
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [ 76  19 111  65] 0.49830619
# Limit box: 1072 256 35 46--->1
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_400_result.txt
# ===========================================
# 1075 222 258 643 42
#
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 1 faces
# 0 [ 0 36 31 80] 0.048138157
# Limit box: 1075 258 31 44--->0
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_400_result.txt
# ===========================================
# 941 236 231 601 58
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 2 faces
# 0 [132  24 163  64] 0.033056874
# Limit box: 1073 260 31 40--->0
# 1 [145  13 163  33] 0.19835216
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_400_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_600_bodies.txt
# ===========================================
# 977 287 52 143 2
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [ 9  0 25 12] 0.95832884
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_600_result.txt
# ===========================================
# 1017 247 150 409 20
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 3 faces
# 0 [ 72  22 112  73] 0.92793137
# Limit box: 1089 269 40 51--->1
# 1 [117  51 130  68] 0.30773368
# 2 [56 77 69 93] 0.20915657
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_600_result.txt
# ===========================================
# 1186 232 263 666 42
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_600_result.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_800_bodies.txt
# ===========================================
# 977 291 51 136 2
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_800_result.txt
# ===========================================
# 1417 194 308 728 19
#
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_800_result.txt
# ===========================================
# 1036 246 157 422 20
#
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 1 faces
# 0 [112  12 143  48] 0.092355594
# Limit box: 1148 258 31 36--->0
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_800_result.txt
# ===========================================
# 1201 232 265 670 42
#
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_19_06_800_result.txt

# %%
# Ejecutar modelo de identificación de mascarilla con test propio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_ignacio.py"

# %%
# Ejecutar modelo de identificación de mascarilla con cuerpos recortados
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_body.py"

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados creando imagenes recortadas
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face.py"

# %%
# Ver imagen
from IPython.display import Image
Image("/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/images/cov_Salida_frame_10_19_32_400_4.jpg", width=500)

# %%
# Ejecutar modelo de identificación de mascarilla con test del repositorio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test.py"

# %%
# Ejecutar modelos de reidentificación
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/gamodel-r50/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r34-amf/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r50-am-lfw/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r100-ii/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-y1-test2/model, 0'
