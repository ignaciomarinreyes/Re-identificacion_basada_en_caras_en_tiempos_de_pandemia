# %%
# Ver características de la gráfica
# !nvidia-smi

# %%
# Montar Drive
from google.colab import drive
drive.mount('/content/gdrive')

# %%
cd "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort"
# Out:
# /content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort

# %%
# Instalar dependencias yolov4
# !pip3 install -r requirements.txt
# !python save_model.py --model yolov4

# %%
# Ejecutar yolov4
#!python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/"
#!python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/"
# !python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/yolov4.py" "/content/gdrive/My Drive/TFG/data/LPATrail19Prueba/"

# %%
# Instalar dependencias insightface
# !pip uninstall -y mxnet && pip install mxnet-cu101
# !pip3 install insightface

# %%
cd "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython/"
# Out:
# /content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython

# %%
# Compilar pyx de cython, para obtener los .c
# !python3 setup.py install

# %%
# Ejecutar InsightFace
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/insightface.py"

# %%
# Ejecutar modelo de identificación de mascarilla con test del repositorio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test.py"

# %%
# Ejecutar modelos de reidentificación
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/gamodel-r50/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r34-amf/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r50-am-lfw/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r100-ii/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-y1-test2/model, 0'

# %%
#Instalar dependencias deepFace
# !pip3 install deepFace
# !pip3 install --upgrade tensorflow
# !pip3 install --upgrade tensorflow-gpu

# %%
#Copiar modelo deepFace a donde lo carga, debido a que no lo puede descargar
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/vgg_face_weights.h5" "/root/.deepface/weights/vgg_face_weights.h5"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/openface_weights.h5" "/root/.deepface/weights/openface_weights.h5"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/deepid_keras_weights.h5" "/root/.deepface/weights/deepid_keras_weights.h5"
# !cp "/content/gdrive/My Drive/TFG/MyAlgorithm/models/arcface_weights.h5" "/root/.deepface/weights/arcface_weights.h5"

# %%
#DeepFace
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -v 
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -die 
#!python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -r1
# !python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py" -ap

# %%
#AlignedReID
#!python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -v
#!python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -d 
#!python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -r1 
# !python3 "/content/gdrive/My Drive/TFG/AlignedReID/AlignedReId.py" -ap
# Out:
# ============ mAP Cuhk03_Resnet50 ====================
# mAP Align 0.9145006667947232
# mAP Original 0.9095610604335045
# ===================================================
# ============ mAP DukeMTMCReID_Resnet50 ====================
# mAP Align 0.916230407795599
# mAP Original 0.8997118213013845
# ===================================================
# ============ mAP Market1501_Resnet50 ====================
# mAP Align 0.9269685308396668
# mAP Original 0.9188325336762393
# ===================================================
# ============ mAP MSMT17_Resnet50 ====================
# mAP Align 0.9179729168019256
# mAP Original 0.896536674126598
# ===================================================

# %%
ls
