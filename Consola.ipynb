# %%
# Ver características de la gráfica
# !nvidia-smi

# %%
# Montar Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
cd "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort"
# Out:
# /content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort

# %%
# Instalar dependencias yolov4
# !pip3 install -r requirements.txt
# !python save_model.py --model yolov4

# %%
# Ejecutar yolov4
# !python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/object_tracker.py" --video ./data/video/test.mp4 --output ./outputs/demo.avi --model yolov4

# %%
# Instalar dependencias insightface
# !pip uninstall -y mxnet && pip install mxnet-cu101
# !pip3 install insightface

# %%
cd "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython/"
# Out:
# /content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython

# %%
# Compilar pyx de cython, para obtener los .c
# !python3 setup.py install

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados sin crear imagenes recortadas, crea los txt de los box de las caras
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face_2.py"
# Out:
# Se han truncado las últimas 5000 líneas del flujo de salida.
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_42_800_bodies.txt
# ===========================================
# 1141 285 62 171 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_43_000_bodies.txt
# ===========================================
# 1138 287 64 178 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_43_200_bodies.txt
# ===========================================
# 1135 285 67 186 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_43_400_bodies.txt
# ===========================================
# 1135 287 66 187 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_43_600_bodies.txt
# ===========================================
# 1130 289 69 194 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# 0 [ 5 11 12 20] 0.11972527
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_43_600_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_43_800_bodies.txt
# ===========================================
# 1128 290 70 198 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_44_000_bodies.txt
# ===========================================
# 1126 292 71 199 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_44_200_bodies.txt
# ===========================================
# 1122 294 73 204 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_44_400_bodies.txt
# ===========================================
# 1120 288 77 215 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# 0 [23 18 38 35] 0.34026915
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_44_400_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_44_600_bodies.txt
# ===========================================
# 1116 286 81 227 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 2 faces
# 0 [32 16 55 47] 0.6841192
# Limit box: 1148 302 23 31--->1 22
# 1 [30  0 56 26] 0.73512554
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_44_600_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_44_800_bodies.txt
# ===========================================
# 1116 287 81 226 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# 0 [32 11 51 36] 0.720572
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_44_800_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_45_000_bodies.txt
# ===========================================
# 1117 289 84 232 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 1 faces
# 0 [20  0 40 25] 0.9363359
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_45_000_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_45_200_bodies.txt
# ===========================================
# 1114 287 87 240 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# 0 [27  9 48 34] 0.9188528
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_45_200_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_45_400_bodies.txt
# ===========================================
# 1110 288 90 243 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [24 14 31 23] 0.23739612
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_45_400_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_45_600_bodies.txt
# ===========================================
# 1114 283 94 257 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [32  5 54 31] 0.9521515
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_45_600_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_45_800_bodies.txt
# ===========================================
# 1114 284 94 255 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [26  3 50 31] 0.9905121
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_45_800_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_46_000_bodies.txt
# ===========================================
# 1109 284 100 273 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 2 faces
# 0 [42  0 67 31] 0.9323103
# Limit box: 1151 284 25 31--->1 22
# 1 [22 21 31 31] 0.08086459
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_46_000_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_46_200_bodies.txt
# ===========================================
# 1109 290 102 276 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 2 faces
# 0 [47  0 74 30] 0.9281482
# 1 [22 14 30 23] 0.051606983
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_46_200_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_46_400_bodies.txt
# ===========================================
# 1112 281 112 307 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 1 faces
# 0 [40  3 66 36] 0.93389964
# Limit box: 1152 284 26 33--->1 22
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_46_400_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_46_600_bodies.txt
# ===========================================
# 1114 283 117 318 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [37 13 65 47] 0.95611227
# Limit box: 1151 296 28 34--->1 22
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_46_600_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_46_800_bodies.txt
# ===========================================
# 1111 277 122 335 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 2 faces
# 0 [61  9 87 39] 0.6060775
# 1 [17 27 26 38] 0.12957764
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_46_800_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_47_000_bodies.txt
# ===========================================
# 1118 278 126 344 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [61 16 90 52] 0.730824
# Limit box: 1179 294 29 36--->1 22
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_47_000_faces.txt
# ===========================================
# 1121 278 29 78 126
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_47_200_bodies.txt
# ===========================================
# 1123 264 138 375 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 2 faces
# 0 [56 11 87 50] 0.87363786
# Limit box: 1179 275 31 39--->1 22
# 1 [ 4 40 13 51] 0.0106509365
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_47_200_faces.txt
# ===========================================
# 1119 282 27 71 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_47_400_bodies.txt
# ===========================================
# 1130 269 142 384 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 2 faces
# 0 [ 69  19 104  64] 0.9642109
# Limit box: 1199 288 35 45--->1 22
# 1 [18 16 30 31] 0.024191758
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_47_400_faces.txt
# ===========================================
# 1116 282 28 71 126
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_47_600_bodies.txt
# ===========================================
# 1144 261 151 411 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [ 95   9 133  55] 0.9825402
# Limit box: 1239 270 38 46--->1 22
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_47_600_faces.txt
# ===========================================
# 1116 282 27 72 126
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 1137 284 32 72 139
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 54) (1, 6, 40, 54)
# (1, 4, 80, 107) (1, 6, 80, 107)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_47_800_bodies.txt
# ===========================================
# 1173 257 159 437 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 1 faces
# 0 [104  21 143  68] 0.9514596
# Limit box: 1277 278 39 47--->1 22
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_47_800_faces.txt
# ===========================================
# 1116 283 28 71 126
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# ===========================================
# 1135 287 28 65 139
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 54) (1, 6, 40, 54)
# (1, 4, 80, 107) (1, 6, 80, 107)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_48_000_bodies.txt
# ===========================================
# 1212 254 171 470 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 1 faces
# 0 [113  19 156  72] 0.88706195
# Limit box: 1325 273 43 53--->1 22
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_48_000_faces.txt
# ===========================================
# 1115 281 28 72 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 2 faces
# 0 [ 5  0 22 18] 0.7819078
# 1 [17  0 27  8] 0.96816796
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_48_000_faces.txt
# ===========================================
# 1137 289 25 60 139
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_48_200_bodies.txt
# ===========================================
# 1264 254 182 491 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 1114 279 29 75 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 1136 290 25 60 139
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_48_400_bodies.txt
# ===========================================
# 1341 252 195 520 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 1114 281 29 73 126
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 0 faces
# ===========================================
# 1134 287 27 65 139
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 52) (1, 6, 40, 52)
# (1, 4, 80, 103) (1, 6, 80, 103)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_48_600_bodies.txt
# ===========================================
# 1355 250 202 536 22
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 1114 281 30 73 126
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ===========================================
# 1134 287 26 65 139
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# ===========================================
# 1501 228 229 577 151
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_48_800_bodies.txt
# ===========================================
# 1115 281 30 75 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 1 faces
# 0 [16  0 29 12] 0.97274643
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_48_800_faces.txt
# ===========================================
# 1134 287 26 64 139
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 1 faces
# 0 [ 0  0 13 17] 0.41921276
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_48_800_faces.txt
# ===========================================
# 1643 246 226 571 151
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_49_000_bodies.txt
# ===========================================
# 1114 282 32 75 126
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 52) (1, 6, 40, 52)
# (1, 4, 80, 103) (1, 6, 80, 103)
# find 0 faces
# ===========================================
# 1738 300 190 513 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_49_200_bodies.txt
# ===========================================
# 1114 282 32 75 126
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 52) (1, 6, 40, 52)
# (1, 4, 80, 103) (1, 6, 80, 103)
# find 0 faces
# ===========================================
# 1786 325 179 482 151
# (1, 4, 24, 20) (1, 6, 24, 20)
# (1, 4, 48, 40) (1, 6, 48, 40)
# (1, 4, 96, 80) (1, 6, 96, 80)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_49_400_bodies.txt
# ===========================================
# 1115 285 32 72 126
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 54) (1, 6, 40, 54)
# (1, 4, 80, 107) (1, 6, 80, 107)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_49_600_bodies.txt
# ===========================================
# 1115 286 34 73 126
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 57) (1, 6, 40, 57)
# (1, 4, 80, 114) (1, 6, 80, 114)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_49_800_bodies.txt
# ===========================================
# 1115 282 36 77 126
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 58) (1, 6, 40, 58)
# (1, 4, 80, 116) (1, 6, 80, 116)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_50_000_bodies.txt
# ===========================================
# 1114 281 37 78 126
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 57) (1, 6, 40, 57)
# (1, 4, 80, 114) (1, 6, 80, 114)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_50_200_bodies.txt
# ===========================================
# 1113 282 38 79 126
# (1, 4, 20, 30) (1, 6, 20, 30)
# (1, 4, 40, 59) (1, 6, 40, 59)
# (1, 4, 80, 117) (1, 6, 80, 117)
# find 1 faces
# 0 [ 0  0 16 24] 0.949197
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_50_200_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_50_400_bodies.txt
# ===========================================
# 1112 280 40 81 126
# (1, 4, 20, 30) (1, 6, 20, 30)
# (1, 4, 40, 60) (1, 6, 40, 60)
# (1, 4, 80, 119) (1, 6, 80, 119)
# find 0 faces
# ===========================================
# 1793 135 173 542 151
# [21:54:53] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 29, 20) (1, 6, 29, 20)
# (1, 4, 57, 40) (1, 6, 57, 40)
# (1, 4, 114, 80) (1, 6, 114, 80)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_50_600_bodies.txt
# ===========================================
# 1109 279 40 83 126
# (1, 4, 20, 30) (1, 6, 20, 30)
# (1, 4, 40, 60) (1, 6, 40, 60)
# (1, 4, 80, 119) (1, 6, 80, 119)
# find 0 faces
# ===========================================
# 1134 289 27 68 139
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# ===========================================
# 1753 131 183 553 151
# (1, 4, 23, 20) (1, 6, 23, 20)
# (1, 4, 45, 40) (1, 6, 45, 40)
# (1, 4, 89, 80) (1, 6, 89, 80)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_50_800_bodies.txt
# ===========================================
# 1109 281 40 82 126
# (1, 4, 20, 30) (1, 6, 20, 30)
# (1, 4, 40, 60) (1, 6, 40, 60)
# (1, 4, 80, 119) (1, 6, 80, 119)
# find 0 faces
# ===========================================
# 1134 290 26 68 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 1711 138 196 553 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_51_000_bodies.txt
# ===========================================
# 1109 282 39 82 126
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 58) (1, 6, 40, 58)
# (1, 4, 80, 116) (1, 6, 80, 116)
# find 0 faces
# ===========================================
# 1134 289 27 71 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 1673 151 192 539 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_51_200_bodies.txt
# ===========================================
# 1108 281 39 83 126
# (1, 4, 20, 29) (1, 6, 20, 29)
# (1, 4, 40, 58) (1, 6, 40, 58)
# (1, 4, 80, 116) (1, 6, 80, 116)
# find 0 faces
# ===========================================
# 1134 288 28 72 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 1628 165 188 521 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_51_400_bodies.txt
# ===========================================
# 1106 281 38 84 126
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 55) (1, 6, 40, 55)
# (1, 4, 80, 109) (1, 6, 80, 109)
# find 0 faces
# ===========================================
# 1134 289 28 72 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 1591 170 186 520 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [38 54 76 93] 0.002603833
# Limit box: 1629 224 38 39--->0 151
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_51_400_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_51_600_bodies.txt
# ===========================================
# 1104 281 39 85 126
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 56) (1, 6, 40, 56)
# (1, 4, 80, 112) (1, 6, 80, 112)
# find 0 faces
# ===========================================
# 1135 289 27 73 139
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 1552 162 188 530 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [ 49  60  87 104] 0.0033480183
# Limit box: 1601 222 38 44--->0 151
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_51_600_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_51_800_bodies.txt
# ===========================================
# 1105 281 38 85 126
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 55) (1, 6, 40, 55)
# (1, 4, 80, 109) (1, 6, 80, 109)
# find 0 faces
# ===========================================
# 1135 286 29 77 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 1518 172 189 523 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 1 faces
# 0 [ 57  65  93 103] 0.001051603
# Limit box: 1575 237 36 38--->0 151
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_51_800_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_52_000_bodies.txt
# ===========================================
# 1105 286 35 78 126
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 54) (1, 6, 40, 54)
# (1, 4, 80, 108) (1, 6, 80, 108)
# find 0 faces
# ===========================================
# 1136 289 27 73 139
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 1497 177 184 519 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_52_200_bodies.txt
# ===========================================
# 1103 280 37 86 126
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 106) (1, 6, 80, 106)
# find 0 faces
# ===========================================
# 1136 287 28 75 139
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 90) (1, 6, 80, 90)
# find 0 faces
# ===========================================
# 1469 171 186 531 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_52_400_bodies.txt
# ===========================================
# 1103 282 37 86 126
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 106) (1, 6, 80, 106)
# find 0 faces
# ===========================================
# 1137 287 29 77 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 1452 174 183 525 151
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_52_600_bodies.txt
# ===========================================
# 1102 282 38 86 126
# (1, 4, 20, 28) (1, 6, 20, 28)
# (1, 4, 40, 55) (1, 6, 40, 55)
# (1, 4, 80, 109) (1, 6, 80, 109)
# find 0 faces
# ===========================================
# 1138 287 30 78 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 1441 176 181 521 151
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_52_800_bodies.txt
# ===========================================
# 1102 281 38 88 126
# (1, 4, 20, 27) (1, 6, 20, 27)
# (1, 4, 40, 53) (1, 6, 40, 53)
# (1, 4, 80, 105) (1, 6, 80, 105)
# find 0 faces
# ===========================================
# 1139 288 29 76 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# 0 [ 2  0 21 21] 0.36878937
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_52_800_faces.txt
# ===========================================
# 1426 183 180 515 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_000_bodies.txt
# ===========================================
# 1102 280 38 92 126
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 0 faces
# ===========================================
# 1140 288 30 78 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 1412 186 181 519 151
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_200_bodies.txt
# ===========================================
# 1778 159 181 553 22
# (1, 4, 26, 20) (1, 6, 26, 20)
# (1, 4, 52, 40) (1, 6, 52, 40)
# (1, 4, 104, 80) (1, 6, 104, 80)
# find 0 faces
# ===========================================
# 1102 281 38 90 126
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 0 faces
# ===========================================
# 1142 286 31 81 139
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 1 faces
# 0 [ 2  0 22 20] 0.83836883
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_200_faces.txt
# ===========================================
# 1397 188 182 515 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [107  30 132  70] 0.54529804
# Limit box: 1504 218 25 40--->1 151
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_200_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_400_bodies.txt
# ===========================================
# 1785 180 158 512 22
# (1, 4, 26, 20) (1, 6, 26, 20)
# (1, 4, 51, 40) (1, 6, 51, 40)
# (1, 4, 101, 80) (1, 6, 101, 80)
# find 1 faces
# 0 [27 27 74 81] 0.78648525
# Limit box: 1812 207 47 54--->1 22
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_400_faces.txt
# ===========================================
# 1102 281 37 91 126
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# ===========================================
# 1144 288 30 78 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# 0 [ 0  0 18 22] 0.95900023
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_400_faces.txt
# ===========================================
# 1388 190 180 509 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [110  22 139  65] 0.008972056
# Limit box: 1498 212 29 43--->0 151
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_400_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_600_bodies.txt
# ===========================================
# 1731 186 169 512 22
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 81, 80) (1, 6, 81, 80)
# find 0 faces
# ===========================================
# 1100 277 40 98 126
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ===========================================
# 1144 286 31 80 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ===========================================
# 1387 195 177 498 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_800_bodies.txt
# ===========================================
# 1671 185 171 516 22
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 81, 80) (1, 6, 81, 80)
# find 1 faces
# 0 [20 29 70 96] 0.24422517
# Limit box: 1691 214 50 67--->1 22
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_53_800_faces.txt
# ===========================================
# 1100 281 39 94 126
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 101) (1, 6, 80, 101)
# find 0 faces
# ===========================================
# 1144 286 32 82 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 1386 201 177 495 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_54_000_bodies.txt
# ===========================================
# 1625 185 170 526 22
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 42, 40) (1, 6, 42, 40)
# (1, 4, 83, 80) (1, 6, 83, 80)
# find 0 faces
# ===========================================
# 1100 288 36 90 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ===========================================
# 1145 289 31 78 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ===========================================
# 1368 209 178 497 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 87) (1, 6, 80, 87)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_54_200_bodies.txt
# ===========================================
# 1596 191 163 517 22
# (1, 4, 22, 20) (1, 6, 22, 20)
# (1, 4, 43, 40) (1, 6, 43, 40)
# (1, 4, 85, 80) (1, 6, 85, 80)
# find 0 faces
# ===========================================
# 1099 282 38 97 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 1143 287 31 81 139
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 1341 214 179 503 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_54_400_bodies.txt
# ===========================================
# 1560 196 159 508 22
# (1, 4, 22, 20) (1, 6, 22, 20)
# (1, 4, 43, 40) (1, 6, 43, 40)
# (1, 4, 85, 80) (1, 6, 85, 80)
# find 0 faces
# ===========================================
# 1099 287 37 94 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ===========================================
# 1142 291 32 82 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 1 faces
# 0 [ 0  0 18 22] 0.83016485
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_54_400_faces.txt
# ===========================================
# 1311 227 187 527 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_54_600_bodies.txt
# ===========================================
# 1520 223 150 479 22
# (1, 4, 22, 20) (1, 6, 22, 20)
# (1, 4, 43, 40) (1, 6, 43, 40)
# (1, 4, 85, 80) (1, 6, 85, 80)
# find 0 faces
# ===========================================
# 1097 280 39 100 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 1138 286 34 88 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 1300 236 186 532 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_54_800_bodies.txt
# ===========================================
# 1475 231 149 472 22
# (1, 4, 22, 20) (1, 6, 22, 20)
# (1, 4, 43, 40) (1, 6, 43, 40)
# (1, 4, 85, 80) (1, 6, 85, 80)
# find 0 faces
# ===========================================
# 1095 277 40 104 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 1137 288 32 82 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 1299 239 187 531 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_55_000_bodies.txt
# ===========================================
# 1449 238 148 464 22
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 42, 40) (1, 6, 42, 40)
# (1, 4, 84, 80) (1, 6, 84, 80)
# find 0 faces
# ===========================================
# 1095 278 39 100 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 1134 291 33 84 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 1304 238 189 532 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_55_200_bodies.txt
# ===========================================
# 1422 244 147 457 22
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 42, 40) (1, 6, 42, 40)
# (1, 4, 83, 80) (1, 6, 83, 80)
# find 0 faces
# ===========================================
# 1095 277 39 102 126
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 1132 291 33 86 139
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 1 faces
# 0 [ 4  0 25 20] 0.038518805
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_55_200_faces.txt
# ===========================================
# 1332 237 185 517 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_55_400_bodies.txt
# ===========================================
# 1096 283 38 100 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 0 faces
# ===========================================
# 1131 291 33 88 139
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 1367 221 186 524 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_55_600_bodies.txt
# ===========================================
# 1349 222 144 452 22
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 42, 40) (1, 6, 42, 40)
# (1, 4, 84, 80) (1, 6, 84, 80)
# find 0 faces
# ===========================================
# 1097 283 39 103 126
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 92) (1, 6, 80, 92)
# find 0 faces
# ===========================================
# 1129 290 34 92 139
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 1410 200 189 536 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_55_800_bodies.txt
# ===========================================
# 1347 229 139 438 22
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 42, 40) (1, 6, 42, 40)
# (1, 4, 84, 80) (1, 6, 84, 80)
# find 0 faces
# ===========================================
# 1098 282 41 107 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 1128 290 35 93 139
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 46) (1, 6, 40, 46)
# (1, 4, 80, 91) (1, 6, 80, 91)
# find 0 faces
# ===========================================
# 1448 186 191 539 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_56_000_bodies.txt
# ===========================================
# 1346 233 134 419 22
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 42, 40) (1, 6, 42, 40)
# (1, 4, 83, 80) (1, 6, 83, 80)
# find 0 faces
# ===========================================
# 1102 284 40 104 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ===========================================
# 1478 177 191 540 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_56_200_bodies.txt
# ===========================================
# 1340 236 131 402 22
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 82, 80) (1, 6, 82, 80)
# find 0 faces
# ===========================================
# 1100 282 42 109 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 0 faces
# ===========================================
# 1491 168 194 549 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_56_400_bodies.txt
# ===========================================
# 1338 241 129 384 22
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 81) (1, 6, 80, 81)
# find 0 faces
# ===========================================
# 1105 284 42 106 126
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 96) (1, 6, 80, 96)
# find 0 faces
# ===========================================
# 1497 166 194 551 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_56_600_bodies.txt
# ===========================================
# 1344 237 127 377 22
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 41) (1, 6, 40, 41)
# (1, 4, 80, 82) (1, 6, 80, 82)
# find 0 faces
# ===========================================
# 1103 281 45 111 126
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 1 faces
# 0 [21  4 44 35] 0.41082978
# Limit box: 1124 285 23 31--->1 126
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_56_600_faces.txt
# ===========================================
# 1495 172 191 542 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_56_800_bodies.txt
# ===========================================
# 1345 239 127 371 22
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 0 faces
# ===========================================
# 1102 282 46 113 126
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ===========================================
# 1489 178 190 538 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_57_000_bodies.txt
# ===========================================
# 1336 243 123 354 22
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ===========================================
# 1103 284 47 112 126
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 51) (1, 6, 40, 51)
# (1, 4, 80, 102) (1, 6, 80, 102)
# find 1 faces
# 0 [ 2  0 22  8] 0.29091156
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_57_000_faces.txt
# ===========================================
# 1480 182 191 537 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_57_200_bodies.txt
# ===========================================
# 1331 251 120 338 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ===========================================
# 1101 282 49 115 126
# (1, 4, 20, 26) (1, 6, 20, 26)
# (1, 4, 40, 52) (1, 6, 40, 52)
# (1, 4, 80, 104) (1, 6, 80, 104)
# find 0 faces
# ===========================================
# 1471 184 190 535 151
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_19_57_400_bodies.txt
# ===========================================
# 1334 244 117 330 22
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 0 faces
# ===========================================
# 1099 281 51 117 126
# ...
# 1047 286 142 369 172
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# 0 [ 67  17 100  62] 0.90935165
# Limit box: 1114 303 33 45--->1 172
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_03_000_faces.txt
# ===========================================
# 628 246 183 532 174
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 83) (1, 6, 80, 83)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_03_200_bodies.txt
# ===========================================
# 1057 278 154 396 172
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 1 faces
# 0 [ 71   6 106  53] 0.8817685
# Limit box: 1128 284 35 47--->1 172
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_03_200_faces.txt
# ===========================================
# 587 252 197 564 174
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_03_400_bodies.txt
# ===========================================
# 1075 279 160 414 172
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# 0 [ 82  14 120  64] 0.98568964
# Limit box: 1157 293 38 50--->1 172
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_03_400_faces.txt
# ===========================================
# 546 239 220 632 174
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_03_600_bodies.txt
# ===========================================
# 1107 280 172 446 172
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 93) (1, 6, 80, 93)
# find 1 faces
# 0 [108  13 149  67] 0.8226161
# Limit box: 1215 293 41 54--->1 172
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_03_600_faces.txt
# ===========================================
# 501 221 240 689 174
# (1, 4, 20, 21) (1, 6, 20, 21)
# (1, 4, 40, 42) (1, 6, 40, 42)
# (1, 4, 80, 84) (1, 6, 80, 84)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_03_800_bodies.txt
# ===========================================
# 1153 273 187 480 172
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 47) (1, 6, 40, 47)
# (1, 4, 80, 94) (1, 6, 80, 94)
# find 1 faces
# 0 [154 116 186 159] 0.034508407
# Limit box: 1307 389 32 43--->0 172
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_03_800_faces.txt
# ===========================================
# 453 224 256 729 174
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# 0 [102  47 146 111] 0.49585047
# Limit box: 555 271 44 64--->1 174
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_03_800_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_04_000_bodies.txt
# ===========================================
# 1224 281 202 506 172
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 1 faces
# 0 [135  21 183  87] 0.98484856
# Limit box: 1359 302 48 66--->1 172
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_04_000_faces.txt
# ===========================================
# 389 218 287 812 174
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# 0 [115  35 165 102] 0.8662446
# Limit box: 504 253 50 67--->1 174
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_04_000_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_04_200_bodies.txt
# ===========================================
# 1300 272 221 545 172
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# ===========================================
# 311 197 309 873 174
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 85) (1, 6, 80, 85)
# find 1 faces
# 0 [117  32 181 119] 0.82695687
# Limit box: 428 229 64 87--->1 174
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_04_200_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_04_400_bodies.txt
# ===========================================
# 1316 271 228 562 172
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 98) (1, 6, 80, 98)
# find 0 faces
# ===========================================
# 234 200 317 886 174
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 43) (1, 6, 40, 43)
# (1, 4, 80, 86) (1, 6, 80, 86)
# find 1 faces
# 0 [121  46 185 113] 0.3412833
# Limit box: 355 246 64 67--->1 174
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_04_400_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_04_600_bodies.txt
# ===========================================
# 126 176 335 915 174
# (1, 4, 20, 22) (1, 6, 20, 22)
# (1, 4, 40, 44) (1, 6, 40, 44)
# (1, 4, 80, 88) (1, 6, 80, 88)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_04_800_bodies.txt
# ===========================================
# 41 155 344 937 174
# (1, 4, 20, 23) (1, 6, 20, 23)
# (1, 4, 40, 45) (1, 6, 40, 45)
# (1, 4, 80, 89) (1, 6, 80, 89)
# find 1 faces
# 0 [ 58  36 162 178] 0.99025035
# Limit box: 99 191 104 142--->1 174
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_04_800_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_05_000_bodies.txt
# ===========================================
# -27 133 341 958 174
# (1, 4, 21, 20) (1, 6, 21, 20)
# (1, 4, 41, 40) (1, 6, 41, 40)
# (1, 4, 82, 80) (1, 6, 82, 80)
# find 1 faces
# 0 [  0  86  74 219] 0.8711213
# Limit box: 0 219 74 133--->1 174
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_05_000_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_05_200_bodies.txt
# ===========================================
# -67 126 351 986 174
# (1, 4, 24, 20) (1, 6, 24, 20)
# (1, 4, 47, 40) (1, 6, 47, 40)
# (1, 4, 93, 80) (1, 6, 93, 80)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_05_400_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_05_600_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_05_800_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_06_000_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_06_200_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_06_400_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_06_600_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_06_800_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_07_000_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_07_200_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_07_400_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_07_600_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_07_800_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_08_000_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_08_200_bodies.txt
# ===========================================
# 902 279 31 76 177
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_08_400_bodies.txt
# ===========================================
# 903 279 29 74 177
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 49) (1, 6, 40, 49)
# (1, 4, 80, 97) (1, 6, 80, 97)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_08_600_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_08_800_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_09_000_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_09_200_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_09_400_bodies.txt
# ===========================================
# 903 278 32 81 177
# (1, 4, 20, 24) (1, 6, 20, 24)
# (1, 4, 40, 48) (1, 6, 40, 48)
# (1, 4, 80, 95) (1, 6, 80, 95)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_09_600_bodies.txt
# ===========================================
# 901 281 32 79 177
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 99) (1, 6, 80, 99)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_09_800_bodies.txt
# ===========================================
# 897 280 31 75 177
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_10_000_bodies.txt
# ===========================================
# 895 281 30 74 177
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_10_200_bodies.txt
# ===========================================
# 894 281 30 74 177
# (1, 4, 20, 25) (1, 6, 20, 25)
# (1, 4, 40, 50) (1, 6, 40, 50)
# (1, 4, 80, 100) (1, 6, 80, 100)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_10_400_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_10_600_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_10_800_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_11_000_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_11_200_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_11_400_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_11_600_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_11_800_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_12_000_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_12_200_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_12_400_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_12_600_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_12_800_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_13_000_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_13_200_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_13_400_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_13_600_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_13_800_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_14_000_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_14_200_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_14_400_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_14_600_bodies.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_tagged_and_result/Salida_frame_10_21_14_800_bodies.txt

# %%
# Ejecutar modelo de identificación de mascarilla con test propio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_ignacio.py"

# %%
# Ejecutar modelo de identificación de mascarilla con cuerpos recortados
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_body.py"

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados creando imagenes recortadas
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face.py"

# %%
# Ver imagen
from IPython.display import Image
Image("/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/images/cov_Salida_frame_10_19_32_400_4.jpg", width=500)

# %%
# Ejecutar modelo de identificación de mascarilla con test del repositorio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test.py"

# %%
# Ejecutar modelos de reidentificación
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/gamodel-r50/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r34-amf/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r50-am-lfw/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r100-ii/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-y1-test2/model, 0'
