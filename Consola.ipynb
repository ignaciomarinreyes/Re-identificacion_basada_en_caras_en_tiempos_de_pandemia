# %%
# Ver características de la gráfica
# !nvidia-smi

# %%
# Montar Drive
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
cd "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort"
# Out:
# /content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort

# %%
# Instalar dependencias yolov4
# !pip3 install -r requirements.txt
# !python save_model.py --model yolov4

# %%
# Ejecutar yolov4
# !python3 "/content/gdrive/My Drive/TFG/Yolov4/yolov4-deepsort/object_tracker.py" --video ./data/video/test.mp4 --output ./outputs/demo.avi --model yolov4

# %%
# Instalar dependencias insightface
# !pip uninstall -y mxnet && pip install mxnet-cu101
# !pip3 install insightface

# %%
cd "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython/"
# Out:
# /content/gdrive/My Drive/TFG/insightface/detection/RetinaFace/rcnn/cython

# %%
# Compilar pyx de cython, para obtener los .c
# !python3 setup.py install

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados sin crear imagenes recortadas, crea los txt de los box de las caras
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face_2.py"
# Out:
# [10:49:45] ../src/nnvm/legacy_json_util.cc:209: Loading symbol saved by previous version v1.5.0. Attempting to upgrade...
# [10:49:45] ../src/nnvm/legacy_json_util.cc:217: Symbol successfully upgraded!
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_200_bodies.txt
# ===========================================
# 1 1262 283 69 180
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_200_faces.txt
# ===========================================
# 7 614 268 135 395
# [10:49:49] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 1 faces
# Limit box: 684 282 34 43--->1 7
# ===========================================
# 1008 940 259 150 412
# [10:49:52] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 50) (1, 6, 135, 50)
# find 1 faces
# Limit box: 1033 279 38 49--->1 1008
# ===========================================
# 2009 1096 286 47 119
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_200_faces.txt
# ===========================================
# 3013 694 276 97 283
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 1 faces
# Limit box: 694 283 25 42--->1 3013
# ===========================================
# 15 1120 307 38 107
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_200_faces.txt
# ===========================================
# 19 822 251 125 310
# [10:49:55] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 14) (1, 6, 34, 14)
# (1, 4, 68, 28) (1, 6, 68, 28)
# (1, 4, 135, 55) (1, 6, 135, 55)
# find 2 faces
# Limit box: 935 292 11 16--->0 19
# Limit box: 873 265 27 34--->1 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_400_bodies.txt
# ===========================================
# 1 1264 284 63 166
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_400_faces.txt
# ===========================================
# 7 629 260 146 426
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 2 faces
# Limit box: 703 269 34 45--->1 7
# Limit box: 662 286 26 31--->0 7
# ===========================================
# 1008 968 259 159 436
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 50) (1, 6, 135, 50)
# find 2 faces
# Limit box: 1020 288 12 16--->0 1008
# Limit box: 1065 285 39 50--->1 1008
# ===========================================
# 15 1117 307 40 109
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_400_faces.txt
# ===========================================
# 19 814 247 129 326
# [10:49:58] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 14) (1, 6, 34, 14)
# (1, 4, 68, 27) (1, 6, 68, 27)
# (1, 4, 135, 54) (1, 6, 135, 54)
# find 2 faces
# Limit box: 875 259 26 34--->1 19
# Limit box: 839 293 11 13--->0 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_600_bodies.txt
# ===========================================
# 1 1261 284 64 165
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_600_faces.txt
# ===========================================
# 3004 1000 296 48 124
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_600_faces.txt
# ===========================================
# 7 654 260 149 438
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 23) (1, 6, 68, 23)
# (1, 4, 135, 46) (1, 6, 135, 46)
# find 2 faces
# Limit box: 741 271 41 50--->1 7
# Limit box: 693 271 28 35--->1 7
# ===========================================
# 1008 1018 255 163 451
# [10:50:01] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 49) (1, 6, 135, 49)
# find 1 faces
# Limit box: 1020 285 12 15--->0 1008
# ===========================================
# 3013 644 264 107 322
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 23) (1, 6, 68, 23)
# (1, 4, 135, 45) (1, 6, 135, 45)
# find 1 faces
# Limit box: 692 272 26 34--->1 3013
# ===========================================
# 1016 948 296 63 173
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_600_faces.txt
# ===========================================
# 19 818 245 132 335
# (1, 4, 34, 14) (1, 6, 34, 14)
# (1, 4, 68, 27) (1, 6, 68, 27)
# (1, 4, 135, 54) (1, 6, 135, 54)
# find 3 faces
# Limit box: 931 294 14 18--->0 19
# Limit box: 871 257 27 35--->1 19
# Limit box: 829 297 14 16--->0 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_800_bodies.txt
# ===========================================
# 1 1261 284 62 161
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_800_faces.txt
# ===========================================
# 3004 1002 299 48 125
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_800_faces.txt
# ===========================================
# 7 687 267 157 460
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 1 faces
# Limit box: 793 286 44 52--->1 7
# ===========================================
# 1008 1079 259 171 463
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 50) (1, 6, 135, 50)
# find 2 faces
# Limit box: 1215 297 34 48--->1 1008
# Limit box: 1133 386 90 104--->0 1008
# ===========================================
# 3013 636 263 109 335
# [10:50:05] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 11) (1, 6, 34, 11)
# (1, 4, 68, 22) (1, 6, 68, 22)
# (1, 4, 135, 44) (1, 6, 135, 44)
# find 1 faces
# Limit box: 659 284 29 41--->0 3013
# ===========================================
# 15 1083 289 43 120
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_800_faces.txt
# ===========================================
# 1016 940 309 60 164
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_52_800_faces.txt
# ===========================================
# 19 818 245 136 347
# [10:50:08] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 14) (1, 6, 34, 14)
# (1, 4, 68, 27) (1, 6, 68, 27)
# (1, 4, 135, 53) (1, 6, 135, 53)
# find 2 faces
# Limit box: 869 258 29 38--->1 19
# Limit box: 924 289 13 15--->0 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_000_bodies.txt
# ===========================================
# 3004 999 294 50 135
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_000_faces.txt
# ===========================================
# 7 729 269 167 483
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 1 faces
# Limit box: 847 271 44 56--->1 7
# ===========================================
# 1008 1141 251 184 500
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 50) (1, 6, 135, 50)
# find 0 faces
# ===========================================
# 3013 629 258 115 355
# (1, 4, 34, 11) (1, 6, 34, 11)
# (1, 4, 68, 22) (1, 6, 68, 22)
# (1, 4, 135, 44) (1, 6, 135, 44)
# find 1 faces
# Limit box: 675 270 27 36--->1 3013
# ===========================================
# 15 1079 304 38 107
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_000_faces.txt
# ===========================================
# 1016 923 297 67 187
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_000_faces.txt
# ===========================================
# 19 812 244 143 363
# (1, 4, 34, 14) (1, 6, 34, 14)
# (1, 4, 68, 27) (1, 6, 68, 27)
# (1, 4, 135, 54) (1, 6, 135, 54)
# find 3 faces
# Limit box: 847 271 42 54--->1 19
# Limit box: 854 489 41 36--->0 19
# Limit box: 884 251 29 39--->1 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_bodies.txt
# ===========================================
# 1 1262 281 62 157
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_faces.txt
# ===========================================
# 2002 796 293 60 174
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_faces.txt
# ===========================================
# 3004 994 288 54 147
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_faces.txt
# ===========================================
# 7 800 273 175 506
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 1 faces
# Limit box: 815 291 14 17--->0 7
# ===========================================
# 1008 1158 250 189 514
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 50) (1, 6, 135, 50)
# find 0 faces
# ===========================================
# 3013 620 255 119 368
# (1, 4, 34, 11) (1, 6, 34, 11)
# (1, 4, 68, 22) (1, 6, 68, 22)
# (1, 4, 135, 44) (1, 6, 135, 44)
# find 0 faces
# ===========================================
# 15 1072 291 40 117
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_faces.txt
# ===========================================
# 1016 915 298 69 191
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_200_faces.txt
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_bodies.txt
# ===========================================
# 1 1260 281 64 164
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_faces.txt
# ===========================================
# 2002 787 290 62 181
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_faces.txt
# ===========================================
# 3004 996 289 54 150
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_faces.txt
# ===========================================
# 7 810 273 180 520
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 1 faces
# Limit box: 810 295 14 17--->1 7
# ===========================================
# 3013 626 262 122 384
# (1, 4, 34, 11) (1, 6, 34, 11)
# (1, 4, 68, 22) (1, 6, 68, 22)
# (1, 4, 135, 43) (1, 6, 135, 43)
# find 1 faces
# Limit box: 704 270 33 43--->1 3013
# ===========================================
# 15 1067 290 40 118
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_400_faces.txt
# ===========================================
# 19 836 234 152 394
# (1, 4, 34, 14) (1, 6, 34, 14)
# (1, 4, 68, 27) (1, 6, 68, 27)
# (1, 4, 135, 53) (1, 6, 135, 53)
# find 1 faces
# Limit box: 903 240 33 41--->1 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_bodies.txt
# ===========================================
# 1 1260 282 65 166
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_faces.txt
# ===========================================
# 2002 779 291 63 183
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_faces.txt
# ===========================================
# 3004 990 282 56 160
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_600_faces.txt
# ===========================================
# 1008 1084 238 224 605
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 50) (1, 6, 135, 50)
# find 0 faces
# ===========================================
# 3013 654 254 133 394
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 23) (1, 6, 68, 23)
# (1, 4, 135, 46) (1, 6, 135, 46)
# find 0 faces
# ===========================================
# 19 851 234 157 410
# [10:50:12] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 26) (1, 6, 68, 26)
# (1, 4, 135, 52) (1, 6, 135, 52)
# find 2 faces
# Limit box: 929 252 34 42--->1 19
# Limit box: 897 406 47 56--->0 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_bodies.txt
# ===========================================
# 1 1260 282 64 165
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_faces.txt
# ===========================================
# 3004 990 282 58 163
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_faces.txt
# ===========================================
# 1008 1159 240 240 650
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 50) (1, 6, 135, 50)
# find 0 faces
# ===========================================
# 3013 668 257 144 421
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 1 faces
# Limit box: 799 292 12 16--->0 3013
# ===========================================
# 15 1064 301 42 122
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_53_800_faces.txt
# ===========================================
# 19 864 233 165 429
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 26) (1, 6, 68, 26)
# (1, 4, 135, 52) (1, 6, 135, 52)
# find 2 faces
# Limit box: 970 244 35 45--->1 19
# Limit box: 901 286 19 25--->0 19
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_bodies.txt
# ===========================================
# 1 1257 286 63 161
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_faces.txt
# ===========================================
# 1008 1172 238 248 671
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 50) (1, 6, 135, 50)
# find 0 faces
# ===========================================
# 3013 700 237 158 461
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 0 faces
# ===========================================
# 15 1060 301 42 124
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_000_faces.txt
# ===========================================
# 2016 873 283 81 230
# [10:50:15] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 48) (1, 6, 135, 48)
# find 2 faces
# Limit box: 901 299 19 24--->1 2016
# Limit box: 921 283 11 12--->1 2016
# ===========================================
# 19 896 222 174 458
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 26) (1, 6, 68, 26)
# (1, 4, 135, 52) (1, 6, 135, 52)
# find 3 faces
# Limit box: 901 298 20 26--->1 19
# Limit box: 1007 244 37 46--->1 19
# Limit box: 920 283 13 15--->0 19
# ===========================================
# 26 1706 237 291 634
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 23) (1, 6, 68, 23)
# (1, 4, 135, 46) (1, 6, 135, 46)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_bodies.txt
# ===========================================
# 1 1258 284 62 159
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_faces.txt
# ===========================================
# 3009 1150 291 23 60
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_200_faces.txt
# ===========================================
# 3013 752 244 167 480
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 1 faces
# Limit box: 789 291 15 20--->0 3013
# ===========================================
# 2016 864 282 83 236
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 48) (1, 6, 135, 48)
# find 1 faces
# Limit box: 917 284 12 14--->0 2016
# ===========================================
# 19 935 219 181 483
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 26) (1, 6, 68, 26)
# (1, 4, 135, 51) (1, 6, 135, 51)
# find 2 faces
# Limit box: 996 285 13 18--->0 19
# Limit box: 1051 238 45 59--->1 19
# ===========================================
# 26 1645 235 320 702
# (1, 4, 34, 14) (1, 6, 34, 14)
# (1, 4, 68, 27) (1, 6, 68, 27)
# (1, 4, 135, 53) (1, 6, 135, 53)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_bodies.txt
# ===========================================
# 1 1259 283 62 159
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_faces.txt
# ===========================================
# 3002 760 290 68 203
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 23) (1, 6, 68, 23)
# (1, 4, 135, 46) (1, 6, 135, 46)
# find 2 faces
# Limit box: 782 298 17 22--->1 3002
# Limit box: 810 300 10 12--->0 3002
# ===========================================
# 3009 1153 291 22 57
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_400_faces.txt
# ===========================================
# 3013 820 228 179 512
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 48) (1, 6, 135, 48)
# find 0 faces
# ===========================================
# 19 990 215 190 510
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 26) (1, 6, 68, 26)
# (1, 4, 135, 51) (1, 6, 135, 51)
# find 0 faces
# ===========================================
# 26 1658 236 336 737
# [10:50:19] ../src/operator/nn/./cudnn/./cudnn_algoreg-inl.h:97: Running performance tests to find the best convolution algorithm, this can take a while... (set the environment variable MXNET_CUDNN_AUTOTUNE_DEFAULT to 0 to disable)
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 48) (1, 6, 135, 48)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_bodies.txt
# ===========================================
# 1 1259 283 61 157
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_600_faces.txt
# ===========================================
# 3002 754 286 72 211
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 3 faces
# Limit box: 798 296 12 15--->1 3002
# Limit box: 771 294 17 21--->1 3002
# Limit box: 780 375 41 68--->0 3002
# ===========================================
# 1007 956 246 193 561
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 2 faces
# Limit box: 994 286 15 19--->0 1007
# Limit box: 980 397 133 141--->1 1007
# ===========================================
# 3013 826 225 185 528
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 48) (1, 6, 135, 48)
# find 2 faces
# Limit box: 994 285 15 21--->0 3013
# Limit box: 904 282 12 16--->0 3013
# ===========================================
# 2016 853 305 78 225
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 1 faces
# Limit box: 907 326 19 25--->0 2016
# ===========================================
# 19 1059 221 195 525
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 26) (1, 6, 68, 26)
# (1, 4, 135, 51) (1, 6, 135, 51)
# find 0 faces
# ###################################
# Leyendo:/content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_bodies.txt
# ===========================================
# 3002 752 284 75 217
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 3 faces
# Limit box: 793 296 12 14--->1 3002
# Limit box: 764 295 18 23--->1 3002
# Limit box: 818 359 8 14--->0 3002
# ===========================================
# 4004 973 282 67 195
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_faces.txt
# ===========================================
# 1007 1026 219 220 616
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 49) (1, 6, 135, 49)
# find 0 faces
# ===========================================
# 2008 1206 217 218 605
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 25) (1, 6, 68, 25)
# (1, 4, 135, 49) (1, 6, 135, 49)
# find 1 faces
# Limit box: 1217 236 55 71--->1 2008
# ===========================================
# 1015 1065 328 41 113
# Box ready: /content/gdrive/My Drive/TFG/data/LPATrail20-Salida_faces_prueba/Salida_frame_10_18_54_800_faces.txt
# ===========================================
# 2016 843 306 79 228
# (1, 4, 34, 12) (1, 6, 34, 12)
# (1, 4, 68, 24) (1, 6, 68, 24)
# (1, 4, 135, 47) (1, 6, 135, 47)
# find 1 faces
# Limit box: 863 306 24 21--->1 2016
# ===========================================
# 19 1074 219 202 544
# (1, 4, 34, 13) (1, 6, 34, 13)
# (1, 4, 68, 26) (1, 6, 68, 26)
# (1, 4, 135, 51) (1, 6, 135, 51)
# find 2 faces
# Limit box: 1217 237 57 70--->1 19
# Limit box: 1079 300 14 15--->0 19

# %%
# Ejecutar modelo de identificación de mascarilla con test propio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_ignacio.py"

# %%
# Ejecutar modelo de identificación de mascarilla con cuerpos recortados
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_body.py"

# %%
# Ejecutar modelo de identificación de mascarilla con caras recortados creando imagenes recortadas
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test_face.py"

# %%
# Ver imagen
from IPython.display import Image
Image("/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/images/cov_Salida_frame_10_19_32_400_4.jpg", width=500)

# %%
# Ejecutar modelo de identificación de mascarilla con test del repositorio
# !python3 "/content/gdrive/My Drive/TFG/insightface/detection/RetinaFaceAntiCov/test.py"

# %%
# Ejecutar modelos de reidentificación
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/gamodel-r50/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r34-amf/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r50-am-lfw/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-r100-ii/model, 0'
# !python3 "/content/gdrive/My Drive/TFG/insightface/deploy/test.py" --model '/content/gdrive/My Drive/TFG/insightface/models/model-y1-test2/model, 0'

# %%
#Instalar dependencias deepFace
# !pip3 install deepFace

# %%
#DeepFace
# !python3 "/content/gdrive/My Drive/TFG/MyAlgorithm/deepFace.py"
